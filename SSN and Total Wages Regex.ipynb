# %%
import re
with open("/home/vimalkumar/Downloads/SET1/0137336000/0137336000_1.txt", "r") as a_file:
    for line in a_file:
        print(line)
        ##x = re.findall('\w{3}-\w{2}-\w{4}',line)
        #if x in line:
            #print(line)
        #if re.findall('\w{3}-\w{2}-\w{4}',line) in line:
        #print(x)
        #stripped_line = line.strip()
        #print(stripped_line)
# Out:
# MISSOURI DEPARTMENT OF LABOR AND INDUSTRIAL RELATIONS
#
# DIVISION OF EMPLOYMENT SECURITY
#
#
#
# Missouri Quarter! Wage Report
#
# CONTINUATION SHEE
#
#
#
# PO Box 888
#
# Jefferson City, MO 65102 0888
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Fim MOOES a wscdavGuareny Conmoaton owdWage open” ‘|
#
# MUGS UP LLC Type or pnnt in ink.
#
# 01-37336-0-00 2/21
#
#
#
# 16 Social Secunty Number | Fist, | Middle 17 Worker Name (Last Name) 18 Tetal Gages P ‘aid 19 Probationary
#
# 495-04-8089 K LIDDELL 293.55 :
#
# 487-76-0666 s E_|MALM 1858.50
#
#
#
# 496-08-2771 I NEWSOM 5148.00
#
#
#
# 500-02-3161 J POLLOCK 10399.00
#
#
#
# 491-25-2801 A PRINCE 1593.93
#
#
#
# 486-21-6939 H REAMS 2308.02
#
#
#
# 490-19-3220 J ROBINSON 998 90
#
#
#
# 486-74-8226 Cc ROMANO 3238 89
#
#
#
# 491-78-0454 E SHELLEY 7491 00
#
# ...

# %%
import re
with open("/home/vimalkumar/Downloads/SET1/0137336000/0137336000_1.txt", "r") as a_file:
    for line in a_file:
        print(len(line))
        #x = re.findall('\w{3}-\w{2}-\w{4}',line)
        #str_words = ' '
        #aa = str_words.join(x)
        #print(aa)
        #if aa in line:
            #print(line)
# Out:
# 54
# 32
# 1
# 30
# 18
# 1
# 11
# 30
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 53
# 33
# 19
# 1
# 107
# 31
# 30
# 1
# 29
# 1
# 31
# 1
# 29
# 1
# 28
# 1
# 30
# 1
# 30
# 1
# 30
# 1
# 33
# 1
# 46
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 106
# 117
# 1
# 26
# 1
# 19
# 1
# 21
# 10
# 1

# %%
import re
with open("/home/vimalkumar/Downloads/SET1/0143313000/0143313000_1.txt", "r") as a_file:
    for line in a_file:
        #print(len(line))
        if len(line) > 5:
            x = re.findall('\d{3}-\d{2}-\d{4}',line)
            y = re.findall(('\s\d[0-9]+.\d[0-9]*'),line)
            #print(y)
            #print(x)
            if len(x) != 0:
                aa = ''.join(x)
                bb = ''.join(y)
                #print(aa)
                #print(bb)
                
                #print(type(aa))
                if  aa in line and bb in line:
                    #print(line)
                    print('SSN : ' , aa)
                    print('Wages :' , bb)
# Out:
# SSN :  490-08-3374
# Wages :  466.09
# SSN :  492-08-5532
# Wages :  1426 69
# SSN :  486-36-6890
# Wages :  2041.98
# SSN :  445-74-3125
# Wages :  6937.13
# SSN :  513-72-8582
# Wages :  593 01
# SSN :  608-90-0724
# Wages :  9992 00
# SSN :  488-78-0777
# Wages :  5999.37
# SSN :  513-90-9730
# Wages :  687 05
# SSN :  489-25-2852
# Wages :  682 38
# SSN :  499-96-2002
# Wages :  5340 89
# SSN :  448-84-8070
# Wages :  228 88
# SSN :  488-21-6495
# Wages :  464 30
# SSN :  496-08-5587
# Wages :  572.57
# SSN :  492-60-4385
# Wages :  21450.00
# SSN :  494-84-1532
# Wages :  4920.03
# SSN :  496-92-5961
# Wages :  2884.01
# SSN :  268-33-5264
# Wages :  325.00
# SSN :  512-86-2990
# Wages :  169.50
# SSN :  500-90-7765
# Wages :  902 00
# SSN :  494-21-6780
# Wages :  154 50

# %%
import re
with open("im.txt", "r") as a_file:
    for line in a_file:
        #print(len(line))
        if len(line) > 5:
            x = re.findall('\d{3}-\d{2}-\d{4}',line)
            y = re.findall('[\s\d[0-9]+.\d[0-9]*] | [\s\d[0-9]+ \d[0-9]*] | [[0-9]+,[0-9]+\s[0-9]*]' ,line)
            print(y)
            #print(x)
            if len(x) != 0:
                aa = ''.join(x)
                bb = ''.join(y)
                #print(aa)
                #print(bb)
                
                #print(type(aa))
                #if  aa in line and bb in line:
                    #print(line)
                    #print('SSN : ' , aa , 'Wages :' , bb)
                    #print('Wages :' , bb)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
im = pytesseract.image_to_string('/home/vimalkumar/Downloads/0384238000.tif')
print(im)
# Out:
# sagen ee
# ’
#
# rt
# @ 1
#
# MISSOURI DIV OF EMPLOYMENT SECURITY
# UNEMPLOYMENT INSURANCE TAX
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 573-751-1995
# QUARTERLY CONTRIBUTION rr ygiprayerAscouNTRO VERE on
# 03-84238-0-00 2021 @ONOT
# File online at yinteractlabor,mo,gov EAU4 USE)
# 3 CALENDAR QUARTER Date Paid
# 1 EMPLOYER NAME AND ADDRESS Ist | | 2nd x | 3rd | | 4th
# RIVER CITY FOOD INC
# 25 LISSADELL LANE MUST HAVE AMOUNTS IN 4, 5, & 6, EVEN IF ZERO
# SAINT CHARLES, MO 63304
# 4 TOTAL WAGES PAID 233,787 61
# 5 WAGES PAID IN EXCESS OF
# 1100000 PER WORKER 106,269 08
# PER YEAR (See Instruction Sheet)
# 6 TAXABLE WAGES
# (Item 4 Minus Item 5) 127,518 53
# 7 TAXES DUE (Multply Item 6 000
# by Your Rate} 0%
# 14 FEDERAL ID NUMBER 43-1748753 >| 8 INTEREST ASSESSMENT DUE
# TO FEDERAL ADVANCES
# ...

# %%
file = open('im.txt', 'w')
file.write(im)
file.close()

# %%
import re
with open("/home/vimalkumar/Downloads/SET1/0143313000/0143313000_1.txt", "r") as a_file:
    for line in a_file:
        #print(len(line))
        if len(line) > 5:
            x = re.findall('\d{3}-\d{2}-\d{4}',line)
            y = re.findall(('\s\d[0-9]+.\d[0-9]*'),line)
            #print(y)
            #print(x)
            if len(x) != 0:
                aa = ''.join(x)
                bb = ''.join(y)
                #print(aa)
                #print(bb)
                
                #print(type(aa))
                if  aa in line and bb in line:
                    #print(line)
                    print('SSN : ' , aa)
                    print('Wages :' , bb)

# %%
import re
with open("im.txt", "r") as a_file:
    for line in a_file:
        #print(line)
        # = '[0-9],[0-9]\s[0-9]'
        if len(line) > 5:
            x = re.findall('\d{3}-\d{2}-\d{4}',line)
            y = re.findall('[0-9]+,[0-9]*\s[0-9]+ | [0-9]* \d{2}' , line)
            if len(x) != 0:
                aa = ''.join(x)
            if len(y)!=0:
                val_list = list(y)
                max_val = max(val_list)
                #print(list(y))
                #print(max_val)
            if aa and str(max_val) in line:
                print('SSN :' , aa , 'Wages :' , max_val)
# Out:
# SSN : 769-30-3745 Wages :  6 00
# SSN : 769-30-3745 Wages :  18 19
# SSN : 364-31-1529 Wages : 1,471 88
# SSN : 407-06-3683 Wages : 9,450 00
# SSN : 429-99-7359 Wages :  647 86
# SSN : 431-93-5074 Wages : 7,178 74
# SSN : 450-37-0516 Wages :  209 94
# SSN : 486-23-6742 Wages :  319 30
# SSN : 487-21-6541 Wages : 2,373 25
# SSN : 487-21-8931 Wages : 1,613 19
# SSN : 489-21-3053 Wages : 2,636 22
# SSN : 490-19-6137 Wages : 1,500 76
# SSN : 491-15-6801 Wages :  4378 00
# SSN : 492-21-9000 Wages : 1,395 96
# SSN : 495-19-8417 Wages : 1,223 07
# SSN : 496-19-7738 Wages : 1,429 09
# SSN : 496-94-5647 Wages : 2,916 86
# SSN : 496-94-5647 Wages : 2,613 39
# SSN : 498-21-5925 Wages : 1,146 18
# SSN : 499-13-7565 Wages :  882 73
# SSN : 499-13-7565 Wages : 1,103 67
# SSN : 500-92-4290 Wages :  728 63
# SSN : 657-14-1130 Wages : 1,905 51
# SSN : 657-14-1130 Wages : 8,048 96
# SSN : 487-84-3792 Wages : 15,056 25
# SSN : 487-94-8409 Wages : 2,392 50
# SSN : 488-11-9123 Wages :  719 60
# ...

# %%
import cv2
import pytesseract
from pytesseract import Output
import pandas as pd

image = cv2.imread('/home/vimalkumar/Downloads/SET1/0196043000/0196043000_1.tif')
result = image.copy()
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# Remove horizontal lines
horizontal_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (40,1))
remove_horizontal = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, horizontal_kernel, iterations=2)
cnts = cv2.findContours(remove_horizontal, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
for c in cnts:
    cv2.drawContours(result, [c], -1, (255,255,255), 5)

# Remove vertical lines
vertical_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1,40))
remove_vertical = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, vertical_kernel, iterations=2)
cnts = cv2.findContours(remove_vertical, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
for c in cnts:
    cv2.drawContours(result, [c], -1, (255,255,255), 5)
#plt.figure(figsize=(15,15))
#plt.imshow(result)

#img = cv2.imread('/home/vimalkumar.s/Documents/backup/2nd page_jpeg/04152020/0430556000.jpeg')
img = cv2.resize(result, (int(result.shape[1] + (result.shape[1] * .1)),
                       int(result.shape[0] + (result.shape[0] * .25))),
                 interpolation=cv2.INTER_AREA)

img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

custom_config = r'-l eng --oem 3 --psm 6 -c tessedit_char_whitelist="ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789-:.$%./@& *"'
d = pytesseract.image_to_data(img_rgb, config=custom_config, output_type=Output.DICT)
df = pd.DataFrame(d)

df1 = df[(df.conf != '-1') & (df.text != ' ') & (df.text != '')]
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

sorted_blocks = df1.groupby('block_num').first().sort_values('top').index.tolist()
for block in sorted_blocks:
    curr = df1[df1['block_num'] == block]
    sel = curr[curr.text.str.len() > 3]
    # sel = curr
    char_w = (sel.width / sel.text.str.len()).mean()
    prev_par, prev_line, prev_left = 0, 0, 0
    text = ''
    for ix, ln in curr.iterrows():
        # add new line when necessary
        if prev_par != ln['par_num']:
            text += '\n'
            prev_par = ln['par_num']
            prev_line = ln['line_num']
            prev_left = 0
        elif prev_line != ln['line_num']:
            text += '\n'
            prev_line = ln['line_num']
            prev_left = 0

        added = 0  # num of spaces that should be added
        if ln['left'] / char_w > prev_left + 1:
            added = int((ln['left']) / char_w) - prev_left
            text += ' ' * added
        text += ln['text'] + ' '
        prev_left += len(ln['text']) + added + 1
    text += '\n'
    print(text)
    
file = open('/home/vimalkumar/Documents/File Samples/extraction/text/file.txt', 'w')
file.write(text)
file.close()
# Out:
#     .
#       as        MISSOURI DEPARTMENT   OF LABOR  AND INDUSTRIAL RELATIONS                                      EAU  10B
#     5  bh    e  DIVISION OF EMPLOYMENT   SECURITY
#                                                                                                              PO Box 888
#       vd        QUARTERLY       WAGE    REPORT                                                 Jefferson City MO 65102-0888
#        wu       CONTINUATION        SHEET
#                                                      Type or print in ink.
#     Printemployers name and account mumberssshownonSs*CCS*S*S*i*:*:*::SCALN@DARQUARTERC ANDERS
#      Form MODES-4 Quarterly Contribution and Wage Report
#                                                                    Ist         2nd  X      3rd          4th
#        NARBELL    INC.
#        01-96043-0-00
#                                                                                         Year 2021
# ...

# %%
import re
with open("/home/vimalkumar/Documents/File Samples/extraction/text/file.txt", "r") as a_file:
    for line in a_file:
        #print(line)
        # = '[0-9],[0-9]\s[0-9]'
        if len(line) > 5:
            x = re.findall('\d{3}-\d{2}-\d{4}',line)
            y = re.findall('[0-9]+,[0-9]*\s[0-9]+ | [0-9]* \d{2} | [0-9]+\.[0-9]*\s[0-9]+ | [0-9]+\.\d{2} | [0-9]+\s\d{2}', line)
            if len(x) != 0:
                aa = ''.join(x)
            if len(y)!=0:
                val_list = list(y)
                max_val = max(val_list)
                #print(list(y))
                #print(max_val)
            if aa and str(max_val) in line:
                print('SSN :' , aa ,'   ' , 'Wages :' , max_val)
# Out:
# SSN : 491-23-7934     Wages :   18
# SSN : 489-23-8190     Wages :   86
# SSN : 499-21-5906     Wages :  1555.06
# SSN : 493-23-1530     Wages :  454.44
# SSN : 621-47-8322     Wages :  416.84
# SSN : 496-19-8944     Wages :  2 72
# SSN : 500-19-2778     Wages :  618.29
# SSN : 356-04-2567     Wages :  2025.08
# SSN : 495-19-1172     Wages :  3035.71
# SSN : 318-80-6644     Wages :   31
# SSN : 318-80-4238     Wages :  3528.00
# SSN : 494-23-9784     Wages :   55
# SSN : 499-94-9819     Wages :  6 30
# SSN : 496-23-9546     Wages :  1107.14
# SSN : 348-92-1332     Wages :  383.46
# SSN : 768-40-9362     Wages :  2648.29
# SSN : 216-69-4944     Wages :  180.56
# SSN : 490-12-5173     Wages :  48.32
# SSN : 486-23-9209     Wages :  1452.15
# SSN : 499-98-3082     Wages :   48
# SSN : 491-23-7934     Wages :  162.23
# SSN : 491-23-7934     Wages :  463.40

# %%
import re
with open("im.txt", "r") as a_file:
    for line in a_file:
        #print(line)
        if len(line) > 5:
            ssn_regex = re.findall('\d{3}-\d{2}-\d{4}',line)
            #print(ssn_regex)
            wages_regex = re.findall('[0-9]+,[0-9]+ \d{2} | [0-9]+ \d{2}',line)
            #print(wages_regex)
            if len(ssn_regex) != 0:
                ssn_out = ''.join(ssn_regex)
                #print(ssn_out)
            if len(wages_regex) > 0:
                wages_out = wages_regex[0]
                #print(wages_out)
                #print(wages_regex[0])
            if ssn_out and wages_out in line:
                print('SSN :' , ssn_out , 'Wages :' , wages_out)
# Out:
# SSN : 769-30-3745 Wages :  6 00
# SSN : 769-30-3745 Wages :  18 19
# SSN : 364-31-1529 Wages : 1,471 88
# SSN : 407-06-3683 Wages : 9,450 00
# SSN : 429-99-7359 Wages :  647 86
# SSN : 431-93-5074 Wages : 7,178 74
# SSN : 450-37-0516 Wages :  209 94
# SSN : 486-23-6742 Wages :  319 30
# SSN : 487-21-6541 Wages : 2,373 25
# SSN : 487-21-8931 Wages : 1,613 19
# SSN : 489-21-3053 Wages : 2,636 22
# SSN : 490-19-6137 Wages : 1,500 76
# SSN : 491-15-6801 Wages :  4378 00
# SSN : 492-21-9000 Wages : 1,395 96
# SSN : 495-19-8417 Wages : 1,223 07
# SSN : 496-19-7738 Wages : 1,429 09
# SSN : 496-94-5647 Wages : 2,916 86
# SSN : 496-94-5647 Wages : 2,613 39
# SSN : 498-21-5925 Wages : 1,146 18
# SSN : 499-13-7565 Wages :  882 73
# SSN : 499-13-7565 Wages : 1,103 67
# SSN : 500-92-4290 Wages :  728 63
# SSN : 657-14-1130 Wages : 1,905 51
# SSN : 657-14-1130 Wages : 46,756 54
# SSN : 487-84-3792 Wages : 15,056 25
# SSN : 487-94-8409 Wages : 2,392 50
# SSN : 488-11-9123 Wages :  719 60
# ...

# %%
file =  open("/home/vimalkumar/Documents/File Samples/extraction/text/file.txt", "r") 
print(file.read())
# Out:
#     .
#       as        MISSOURI DEPARTMENT   OF LABOR  AND INDUSTRIAL RELATIONS                                      EAU  10B
#     5  bh    e  DIVISION OF EMPLOYMENT   SECURITY
#                                                                                                              PO Box 888
#       vd        QUARTERLY       WAGE    REPORT                                                 Jefferson City MO 65102-0888
#        wu       CONTINUATION        SHEET
#                                                      Type or print in ink.
#     Printemployers name and account mumberssshownonSs*CCS*S*S*i*:*:*::SCALN@DARQUARTERC ANDERS
#      Form MODES-4 Quarterly Contribution and Wage Report
#                                                                    Ist         2nd  X      3rd          4th
#        NARBELL    INC.
#        01-96043-0-00
#                                                                                         Year 2021
# ...

# %%
file =  open("/home/vimalkumar/Documents/File Samples/extraction/text/file.txt", "r") 
print(file.read(80))
# Out:
#     .
#       as        MISSOURI DEPARTMENT   OF LABOR  AND INDUSTRIAL RELATIONS
