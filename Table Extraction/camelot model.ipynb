# %%
import os

# %%
os.getcwd()
# Out:
# '/home/vimal/Documents/python'

# %%
pip install "camelot-py[cv]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import camelot

# %%
tables = camelot.read_pdf('sample.pdf', flavor='stream', pages='0-3')

# %%
tables
# Out:
# <TableList n=4>

# %%
tables[2]  # 2 is the index
# Out:
# <Table shape=(23, 7)>

# %%
df2=tables[2].df
df2
# Out:
#                     0                                             1       2  \
# 0                      State-wise GST Collections during March 2020
# 1               State                                        Mar-19  Mar-20
# 2   Jammu and Kashmir                                           388     276
# 3    Himachal Pradesh                                           660     596
# 4              Punjab                                         1,166   1,181
# 5          Chandigarh                                           162     153
# 6         Uttarakhand                                         1,451   1,195
# 7             Haryana                                         4,561   4,874
# 8               Delhi                                         3,722   3,273
# 9           Rajasthan                                         3,132   2,820
# 10      Uttar Pradesh                                         5,548   5,294
# ...

# %%
df3=tables[3].df
df3
# Out:
#                          0       1       2     3         4         5     6
# 0             Chhattisgarh   2,143   2,093   -2%    22,932    24,160    5%
# 1           Madhya Pradesh   2,624   2,407   -8%    25,683    28,354   10%
# 2                  Gujarat   6,521   6,820    5%    73,440    78,923    7%
# 3            Daman and Diu     103      95   -8%     1,105     1,155    5%
# 4   Dadra and Nagar Haveli     174     169   -3%     1,718     1,810    5%
# 5              Maharashtra  15,596  15,002   -4%  1,70,289  1,85,917    9%
# 6                Karnataka   6,983   7,144    2%    78,763    83,408    6%
# 7                      Goa     389     316  -19%     4,103     4,280    4%
# 8              Lakshadweep       1       1   54%        20        20    2%
# 9                   Kerala   1,635   1,475  -10%    16,343    19,234   18%
# 10              Tamil Nadu   6,941   6,178  -11%    70,562    74,430    5%
# ...

# %%
df4=tables[1].df
df4
# Out:
#                                                     0
# 0          Posted On: 01 APR 2020 5:05PM by PIB Delhi
# 1   The gross GST revenue collected in the month o...
# 2   is Rs. 19,183 crore, SGST is Rs. 25,601 crore,...
# 3   crore collected on imports) and Cess is Rs. 8,...
# 4   imports). The total number of GSTR-3B Returns ...
# 5                                  2020 is 76.5 lakh.
# 6   The government has settled Rs. 19,718 crore to...
# 7   as regular settlement. Inaddition,Centre has a...
# 8   crores on ad-hoc basis in the ratio of 50:50 b...
# 9   earned by Central Government and the State Gov...
# 10  March,2020 is Rs. 41,901 crore for CGST and Rs...
# 11  The  GST  revenues  during  the  month  of  Ma...
# 12  anegative growth of 4% over the revenue during...
# 13  GST collected from import of goods, the total ...
# 14  in comparison to the revenue during March, 201...
# 15  has shown a negative growth of (-) 23% as comp...
# ...

# %%
type(df4)
# Out:
# pandas.core.frame.DataFrame

# %%
from PIL import Image

# %%
image1 = Image.open(r'0298801000.jpeg')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))
plt.imshow(image1)

# %%
im1 = image1.convert('RGB')
im1.save(r'myFirstImage.pdf')

# %%
tables1 = camelot.read_pdf('myFirstImage.pdf', flavor='stream', pages='0-1')

# %%
tables1
# Out:
# <TableList n=0>

# %%
image2 = Image.open(r'0113647000.jpeg')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,15))
plt.imshow(image2)

# %%
im2= image2.convert('RGB')
im2.save(r'sample2.pdf')

# %%
tables5 = camelot.read_pdf('sample2.pdf', flavor='stream', pages='0-1')

# %%
tables5
# Out:
# <TableList n=0>
