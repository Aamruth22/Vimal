# %%
from PIL import Image,ImageStat,ImageOps
import cv2
import pytesseract
import numpy as np
import pandas as pd
import datetime
from fuzzywuzzy import fuzz
import fitz
import os
import re
import glob
import time
import img2pdf
import shutil
import keras
from PIL import ImageEnhance
from keras.preprocessing.image import load_img,img_to_array
from tensorflow.keras.preprocessing import image
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
import matplotlib.pyplot as plt


start = time.time()
#print(start)
print(datetime.datetime.now())

#pdf_file = 'Lindbergh Lawns Tract  BL 1,2,3.pdf'

file_path = '/home/vimalkumar/Documents/Marion Clark/docs/pdf'
#excel_path = '/home/vimalkumar/Documents/stewart/excel_output'

for pdf_file in sorted(os.listdir(file_path)):
    print(pdf_file)
    in_path = os.path.join(file_path,pdf_file)
    out_path = os.path.join('/home/vimalkumar/Documents/Marion Clark/docs/images',
                            str(os.path.splitext(pdf_file)[0]))

    os.makedirs(out_path)

    doc = fitz.open(in_path)
    
    print('No of Images: ',len(doc))

    for i in range(len(doc)):
        doc = fitz.open(in_path)
        page = doc.load_page(i)  # number of page
        pix = page.get_pixmap(matrix=fitz.Matrix(150/72,150/72))# for 150dpi
        file_name = str(i+1000 + 1)       
        pix.pil_save(os.path.join(out_path,file_name+'.jpeg'))
# Out:
# /home/vimalkumar/Documents/Python_new_1/cde_venv/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# 2022-03-21 11:17:14.852183: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-21 11:17:14.852216: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-03-21 11:17:43.060507
# Batch 4.pdf
# No of Images:  55
# Batch 9.pdf
# No of Images:  52

# %%
inception_model = keras.models.load_model('/home/vimalkumar/Documents/Python_new_1/SOFTCO/New project/stewart_inception_model.h5')
dic = {0:'Blank',1:'Not Blank'}
path = '/home/vimalkumar/Documents/stewart/1/2022-02-21/1'
for im in os.listdir(path):
    #print(cnt)
    #print(cnt,'  ',im)
    #cnt = cnt + 1
    img = image.load_img(os.path.join(path,im),
                     target_size=(224,224))
    plt.imshow(img)
    plt.show()

    x = image.img_to_array(img)
    x = x/255
    x = np.expand_dims(x,axis=0)
    images = np.vstack([x])
    val = inception_model.predict(images)
    #print(val)

    a=np.argmax(val,axis=1)
    output_inception = dic[a[0]]
    print(output_inception)
# Out:
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank
# Not Blank

# %%
from PIL import Image,ImageStat,ImageOps
import cv2
import pytesseract
import numpy as np
import pandas as pd
import datetime
from fuzzywuzzy import fuzz
import fitz
import os
import re
import glob
import time
import img2pdf
import shutil
import keras
from PIL import ImageEnhance
from keras.preprocessing.image import load_img,img_to_array
from tensorflow.keras.preprocessing import image
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
import matplotlib.pyplot as plt


start = time.time()
#print(start)
print(datetime.datetime.now())

#pdf_file = 'Lindbergh Lawns Tract  BL 1,2,3.pdf'

file_path = '/home/vimalkumar/Downloads/zip_test/pdf'
#excel_path = '/home/vimalkumar/Documents/stewart/excel_output'

for pdf_file in sorted(os.listdir(file_path)):
    print(pdf_file)
    in_path = os.path.join(file_path,pdf_file)
    out_path = os.path.join('/home/vimalkumar/Downloads/zip_test/image',
                            str(os.path.splitext(pdf_file)[0]))

    os.makedirs(out_path)

    doc = fitz.open(in_path)
    
    print('No of Images: ',len(doc))

    for i in range(len(doc)):
        doc = fitz.open(in_path)
        page = doc.load_page(i)  # number of page
        pix = page.get_pixmap(matrix=fitz.Matrix(150/72,150/72))# for 150dpi
        file_name = str(i+1000 + 1)       
        pix.pil_save(os.path.join(out_path,file_name+'.jpeg'))
# Out:
# /home/vimalkumar/Documents/Python_new_1/cde_venv/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# 2022-03-18 16:01:23.326462: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-18 16:01:23.326493: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-03-18 16:01:36.464849
# Batch 2.pdf
# No of Images:  4
