# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
# from tensorflow.keras.applications.inception_v3 import InceptionV3
# #from keras.applications.vgg16 import VGG16
# from tensorflow.keras.applications.inception_v3 import preprocess_input
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
#import matplotlib.pyplot as plt
# Out:
# 2022-03-23 11:13:56.142800: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-23 11:13:56.142839: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# re-size all the images to this
IMAGE_SIZE = [224, 224]

train_path = '/home/vimalkumar/Documents/Stewart/CNN/Angle_cnn/train'
#valid_path = '/home/vimalkumar/Documents/softco/CNN/CNN/test'

# %%
vgg = VGG16(input_shape=(224,224,3), weights='imagenet', include_top=False)
# Out:
# 2022-03-23 11:14:19.692564: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-23 11:14:19.692655: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-23 11:14:19.692686: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (IG154): /proc/driver/nvidia/version does not exist
# 2022-03-23 11:14:19.693173: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# don't train existing weights
for layer in vgg.layers:
    layer.trainable = False

# %%
folders = glob('/home/vimalkumar/Documents/Stewart/CNN/Angle_cnn/train/*')

# %%
x = Flatten()(vgg.output)

# %%
prediction = Dense(len(folders), activation='softmax')(x)

# create a model object
model = Model(inputs=vgg.input, outputs=prediction)

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# Use the Image Data Generator to import the images from the dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                  
                                  validation_split=0.20)

#test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Make sure you provide the same target size as initialied for the image size
training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (224, 224),
                                                 batch_size = 2,
                                                 class_mode = 'categorical',
                                                subset = 'training')

test_set = train_datagen.flow_from_directory(train_path,
                                            target_size = (224, 224),
                                            batch_size = 2,
                                            class_mode = 'categorical',
                                           subset = 'validation')
# Out:
# Found 1065 images belonging to 4 classes.
# Found 265 images belonging to 4 classes.

# %%
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=10,
  #steps_per_epoch=len(training_set),
  #validation_steps=len(test_set)
)
# Out:
# /home/vimalkumar/Documents/Python_new_1/cde_venv/lib/python3.8/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2022-03-23 11:15:10.486414: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/10
# 2022-03-23 11:15:12.427009: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 25690112 exceeds 10% of free system memory.
# 2022-03-23 11:15:13.139679: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 25690112 exceeds 10% of free system memory.
#   1/533 [..............................] - ETA: 26:09 - loss: 0.6287 - accuracy: 1.0000
# 2022-03-23 11:15:13.796622: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 25690112 exceeds 10% of free system memory.
# 2022-03-23 11:15:13.805246: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 25690112 exceeds 10% of free system memory.
#   2/533 [..............................] - ETA: 2:33 - loss: 3.4656 - accuracy: 0.5000
# 2022-03-23 11:15:14.086242: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 25690112 exceeds 10% of free system memory.
# 533/533 [==============================] - 221s 410ms/step - loss: 0.7491 - accuracy: 0.7671 - val_loss: 0.4334 - val_accuracy: 0.8075
# Epoch 2/10
# 533/533 [==============================] - 216s 405ms/step - loss: 0.2294 - accuracy: 0.9305 - val_loss: 0.3660 - val_accuracy: 0.8755
# Epoch 3/10
# 533/533 [==============================] - 208s 391ms/step - loss: 0.1107 - accuracy: 0.9718 - val_loss: 0.5199 - val_accuracy: 0.8566
# Epoch 4/10
# 533/533 [==============================] - 211s 396ms/step - loss: 0.1647 - accuracy: 0.9521 - val_loss: 0.9466 - val_accuracy: 0.8528
# Epoch 5/10
# 533/533 [==============================] - 210s 393ms/step - loss: 0.1737 - accuracy: 0.9521 - val_loss: 0.7664 - val_accuracy: 0.8491
# Epoch 6/10
# 533/533 [==============================] - 206s 387ms/step - loss: 0.1543 - accuracy: 0.9577 - val_loss: 0.7257 - val_accuracy: 0.8491
# Epoch 7/10
# 533/533 [==============================] - 215s 404ms/step - loss: 0.1100 - accuracy: 0.9737 - val_loss: 0.2198 - val_accuracy: 0.9396
# Epoch 8/10
# 533/533 [==============================] - 216s 406ms/step - loss: 0.0463 - accuracy: 0.9822 - val_loss: 0.2227 - val_accuracy: 0.9434
# Epoch 9/10
# 533/533 [==============================] - 210s 394ms/step - loss: 0.0668 - accuracy: 0.9803 - val_loss: 0.9430 - val_accuracy: 0.8264
# Epoch 10/10
# 533/533 [==============================] - 217s 408ms/step - loss: 0.1378 - accuracy: 0.9671 - val_loss: 0.4832 - val_accuracy: 0.8981

# %%
model.save('vgg16_stewart_rotation.h5')

# %%
import os
import keras
from keras.preprocessing.image import load_img,img_to_array
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model,load_model

import numpy as np
import pandas as pd
from glob import glob

# %%
model = load_model('vgg16_stewart_rotation.h5')
# Out:
# 2022-03-23 12:15:34.746019: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-03-23 12:15:34.746079: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-23 12:15:34.746111: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (IG154): /proc/driver/nvidia/version does not exist
# 2022-03-23 12:15:34.746579: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_path = '/home/vimalkumar/Documents/Stewart/CNN/Angle_cnn/train'
folders = glob('/home/vimalkumar/Documents/Stewart/CNN/Angle_cnn/train/*')

keys = []
values = []
for key in range(len(folders)):
    #print(key)
    keys.append(key)
for path in os.listdir(train_path):
    #print(path)
    values.append(path)
dic = dict(list(zip(keys,sorted(values))))
print(dic)
# Out:
# {0: '0 degree', 1: '180 degree', 2: '270 degree', 3: '90 degree'}

# %%
def predict_image(path):
    img = image.load_img(path, 
                         target_size=(224,224))
#     plt.figure(figsize=(15,20))
#     plt.imshow(img)
    plt.show()

    x = image.img_to_array(img)
    x = x/255
    x = np.expand_dims(x,axis=0)
    images = np.vstack([x])
    val = model.predict(images)
    print(val)

    a=np.argmax(val,axis=1)
    #print(a)
    print('Image rotated Angle : ',dic[a[0]])

# %%
path = '/home/vimalkumar/Documents/Stewart/CNN/stewart test/270 degree'
count = 1
for i in os.listdir(path):
    print(count ,'  ',i)
    count += 1
    img = image.load_img(os.path.join(path,i), 
                         target_size=(224,224))
    #     plt.figure(figsize=(15,20))
    #     plt.imshow(img)
    plt.show()

    x = image.img_to_array(img)
    x = x/255
    x = np.expand_dims(x,axis=0)
    images = np.vstack([x])
    val = model.predict(images)
    #print(val)

    a=np.argmax(val,axis=1)
    #print(a)
    print('Image rotated Angle : ',dic[a[0]])
# Out:
# 1    b14_33.png
# 2022-03-23 12:15:43.935242: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Image rotated Angle :  270 degree
# 2    b14_37.png
# Image rotated Angle :  270 degree
# 3    b8_40.png
# Image rotated Angle :  270 degree
# 4    b8_19.png
# Image rotated Angle :  270 degree
# 5    b8_101.png
# Image rotated Angle :  270 degree
# 6    b14_43.png
# Image rotated Angle :  270 degree
# 7    b8_69.png
# Image rotated Angle :  270 degree
# 8    b14_23.png
# Image rotated Angle :  270 degree
# 9    b8_20.png
# Image rotated Angle :  270 degree
# 10    b14_30.png
# Image rotated Angle :  270 degree
# 11    b8_83.png
# Image rotated Angle :  270 degree
# 12    b14_44.png
# Image rotated Angle :  270 degree
# 13    b14_67.png
# Image rotated Angle :  270 degree
# 14    b14_78.png
# Image rotated Angle :  270 degree
# 15    b8_72.png
# Image rotated Angle :  270 degree
# 16    b8_55.png
# Image rotated Angle :  270 degree
# 17    b8_42.png
# Image rotated Angle :  270 degree
# 18    b8_32.png
# Image rotated Angle :  270 degree
# 19    b14_54.png
# Image rotated Angle :  270 degree
# 20    b8_58.png
# Image rotated Angle :  270 degree
# 21    b8_86.png
# Image rotated Angle :  270 degree
# 22    b14_61.png
# Image rotated Angle :  90 degree
# 23    b8_17.png
# Image rotated Angle :  270 degree
# 24    b8_82.png
# Image rotated Angle :  270 degree
# 25    b14_8.png
# Image rotated Angle :  270 degree
# 26    b14_84.png
# Image rotated Angle :  270 degree
# 27    b14_40.png
# Image rotated Angle :  270 degree
# 28    b8_88.png
# Image rotated Angle :  270 degree
# 29    b14_7.png
# Image rotated Angle :  270 degree
# 30    b8_5.png
# Image rotated Angle :  270 degree
# 31    b8_60.png
# Image rotated Angle :  270 degree
# 32    b8_79.png
# Image rotated Angle :  270 degree
# 33    b14_12.png
# Image rotated Angle :  270 degree
# 34    b14_0.png
# Image rotated Angle :  270 degree
# 35    b8_0.png
# Image rotated Angle :  270 degree
# 36    b8_59.png
# Image rotated Angle :  270 degree
# 37    b8_67.png
# Image rotated Angle :  270 degree
# 38    b8_41.png
# Image rotated Angle :  270 degree
# 39    b8_71.png
# Image rotated Angle :  270 degree
# 40    b14_22.png
# Image rotated Angle :  270 degree
# 41    b8_85.png
# Image rotated Angle :  270 degree
# 42    b14_38.png
# Image rotated Angle :  270 degree
# 43    b14_1.png
# Image rotated Angle :  270 degree
# 44    b8_54.png
# Image rotated Angle :  270 degree
# 45    b8_8.png
# Image rotated Angle :  270 degree
# 46    b8_43.png
# Image rotated Angle :  270 degree
# 47    b14_86.png
# Image rotated Angle :  270 degree
# 48    b8_34.png
# Image rotated Angle :  270 degree
# 49    b14_15.png
# Image rotated Angle :  270 degree
# 50    b8_23.png
# Image rotated Angle :  270 degree
# 51    b14_68.png
# Image rotated Angle :  270 degree
# 52    b14_56.png
# Image rotated Angle :  270 degree
# 53    b8_56.png
# Image rotated Angle :  270 degree
# 54    b8_3.png
# Image rotated Angle :  270 degree
# 55    b14_16.png
# Image rotated Angle :  270 degree
# 56    b8_53.png
# Image rotated Angle :  270 degree
# 57    b14_70.png
# Image rotated Angle :  270 degree
# 58    b8_9.png
# Image rotated Angle :  270 degree
# 59    b14_85.png
# Image rotated Angle :  270 degree
# 60    b8_48.png
# Image rotated Angle :  270 degree
# 61    b14_58.png
# Image rotated Angle :  270 degree
# 62    b14_62.png
# Image rotated Angle :  270 degree
# 63    b8_7.png
# Image rotated Angle :  270 degree
# 64    b14_28.png
# Image rotated Angle :  270 degree
# 65    b8_33.png
# Image rotated Angle :  270 degree
# 66    b14_14.png
# Image rotated Angle :  270 degree
# 67    b14_10.png
# Image rotated Angle :  270 degree
# 68    b14_65.png
# Image rotated Angle :  90 degree
# 69    b8_21.png
# Image rotated Angle :  270 degree
# 70    b14_51.png
# Image rotated Angle :  270 degree
# 71    b8_22.png
# Image rotated Angle :  270 degree
# 72    b8_6.png
# Image rotated Angle :  270 degree
# 73    b8_81.png
# Image rotated Angle :  270 degree
# 74    b14_39.png
# Image rotated Angle :  270 degree
# 75    b8_27.png
# Image rotated Angle :  270 degree
# 76    b14_26.png
# Image rotated Angle :  270 degree
# 77    b14_21.png
# Image rotated Angle :  270 degree
# 78    b14_24.png
# Image rotated Angle :  270 degree
# 79    b14_45.png
# Image rotated Angle :  270 degree
# 80    b8_64.png
# Image rotated Angle :  270 degree
# 81    b8_37.png
# Image rotated Angle :  270 degree
# 82    b8_29.png
# Image rotated Angle :  270 degree
# 83    b8_80.png
# Image rotated Angle :  270 degree
# 84    b8_107.png
# Image rotated Angle :  270 degree
# 85    b8_35.png
# Image rotated Angle :  270 degree
# 86    b14_87.png
# Image rotated Angle :  270 degree
# 87    b8_15.png
# Image rotated Angle :  270 degree
# 88    b14_46.png
# Image rotated Angle :  270 degree
# 89    b8_66.png
# Image rotated Angle :  270 degree
# 90    b8_91.png
# Image rotated Angle :  270 degree
# 91    b8_1.png
# Image rotated Angle :  270 degree
# 92    b8_4.png
# Image rotated Angle :  270 degree
# 93    b14_11.png
# Image rotated Angle :  270 degree
# 94    b14_83.png
# Image rotated Angle :  270 degree
# 95    b8_78.png
# Image rotated Angle :  270 degree
# 96    b8_12.png
# Image rotated Angle :  270 degree
# 97    b8_61.png
# Image rotated Angle :  270 degree
# 98    b8_46.png
# Image rotated Angle :  270 degree
# 99    b8_97.png
# Image rotated Angle :  270 degree
# 100    b8_51.png
# Image rotated Angle :  270 degree
# 101    b8_28.png
# Image rotated Angle :  270 degree
# 102    b8_44.png
# Image rotated Angle :  270 degree
# 103    b8_13.png
# Image rotated Angle :  270 degree
# 104    b14_52.png
# Image rotated Angle :  270 degree
# 105    b8_38.png
# Image rotated Angle :  270 degree
# 106    b8_16.png
# Image rotated Angle :  270 degree
# 107    b8_30.png
# Image rotated Angle :  270 degree
# 108    b8_36.png
# Image rotated Angle :  270 degree
# 109    b8_25.png
# Image rotated Angle :  270 degree
# 110    b8_57.png
# Image rotated Angle :  270 degree
# 111    b8_87.png
# Image rotated Angle :  270 degree
# 112    b8_39.png
# Image rotated Angle :  270 degree
# 113    b8_100.png
# Image rotated Angle :  270 degree
# 114    b14_82.png
# Image rotated Angle :  270 degree
# 115    b14_34.png
# Image rotated Angle :  270 degree
# 116    b14_49.png
# Image rotated Angle :  270 degree
# 117    b14_76.png
# Image rotated Angle :  270 degree
# 118    b14_66.png
# Image rotated Angle :  270 degree
# 119    b14_36.png
# Image rotated Angle :  270 degree
# 120    b8_18.png
# Image rotated Angle :  270 degree
# 121    b8_10.png
# Image rotated Angle :  270 degree
# 122    b8_102.png
# Image rotated Angle :  270 degree
# 123    b14_75.png
# Image rotated Angle :  90 degree
# 124    b8_108.png
# Image rotated Angle :  270 degree
# 125    b8_70.png
# Image rotated Angle :  270 degree
# 126    b14_6.png
# Image rotated Angle :  270 degree
# 127    b14_29.png
# Image rotated Angle :  270 degree
# 128    b14_79.png
# Image rotated Angle :  270 degree
# 129    b14_59.png
# Image rotated Angle :  0 degree
# 130    b8_77.png
# Image rotated Angle :  270 degree
# 131    b8_47.png
# Image rotated Angle :  270 degree
# 132    b14_55.png
# Image rotated Angle :  270 degree
# 133    b14_5.png
# Image rotated Angle :  270 degree
# 134    b8_103.png
# Image rotated Angle :  270 degree
# 135    b14_31.png
# Image rotated Angle :  270 degree
# 136    b14_72.png
# Image rotated Angle :  270 degree
# 137    b8_76.png
# Image rotated Angle :  270 degree
# 138    b8_62.png
# Image rotated Angle :  270 degree
# 139    b8_26.png
# Image rotated Angle :  270 degree
# 140    b8_90.png
# Image rotated Angle :  270 degree
# 141    b8_105.png
# Image rotated Angle :  270 degree
# 142    b8_49.png
# Image rotated Angle :  270 degree
# 143    b8_11.png
# Image rotated Angle :  270 degree
# 144    b14_50.png
# Image rotated Angle :  270 degree
# 145    b14_35.png
# Image rotated Angle :  270 degree
# 146    b8_93.png
# Image rotated Angle :  270 degree
# 147    b14_74.png
# Image rotated Angle :  270 degree
# 148    b8_92.png
# Image rotated Angle :  270 degree
# 149    b8_52.png
# Image rotated Angle :  270 degree
# 150    b14_9.png
# Image rotated Angle :  270 degree
# 151    b14_17.png
# Image rotated Angle :  270 degree
# 152    b14_81.png
# Image rotated Angle :  270 degree
# 153    b8_104.png
# Image rotated Angle :  270 degree
# 154    b8_2.png
# Image rotated Angle :  270 degree
# 155    b8_89.png
# Image rotated Angle :  270 degree
# 156    b14_18.png
# Image rotated Angle :  270 degree
# 157    b14_48.png
# Image rotated Angle :  270 degree
# 158    b14_13.png
# Image rotated Angle :  270 degree
# 159    b8_74.png
# Image rotated Angle :  270 degree
# 160    b8_45.png
# Image rotated Angle :  270 degree
# 161    b8_50.png
# Image rotated Angle :  270 degree
# 162    b8_31.png
# Image rotated Angle :  270 degree
# 163    b14_2.png
# Image rotated Angle :  270 degree
# 164    b8_75.png
# Image rotated Angle :  270 degree
# 165    b14_25.png
# Image rotated Angle :  270 degree
# 166    b14_4.png
# Image rotated Angle :  270 degree
# 167    b14_60.png
# Image rotated Angle :  270 degree
# 168    b8_24.png
# Image rotated Angle :  270 degree
# 169    b14_27.png
# Image rotated Angle :  270 degree
# 170    b14_64.png
# Image rotated Angle :  270 degree
# 171    b8_68.png
# Image rotated Angle :  270 degree
# 172    b14_42.png
# Image rotated Angle :  270 degree
# 173    b8_84.png
# Image rotated Angle :  270 degree
# 174    b8_94.png
# Image rotated Angle :  270 degree
# 175    b14_80.png
# Image rotated Angle :  270 degree
# 176    b8_106.png
# Image rotated Angle :  270 degree
# 177    b8_65.png
# Image rotated Angle :  270 degree
# 178    b14_3.png
# Image rotated Angle :  270 degree

# %%
path = '/home/vimalkumar/Documents/Stewart/CNN/stewart test/180 degree'
count = 1
for i in os.listdir(path):
    print(count ,'  ',i)
    count += 1
    img = image.load_img(os.path.join(path,i), 
                         target_size=(224,224))
    #     plt.figure(figsize=(15,20))
    #     plt.imshow(img)
    plt.show()

    x = image.img_to_array(img)
    x = x/255
    x = np.expand_dims(x,axis=0)
    images = np.vstack([x])
    val = model.predict(images)
    #print(val)

    a=np.argmax(val,axis=1)
    #print(a)
    print('Image rotated Angle : ',dic[a[0]])
# Out:
# 1    b14_33.png
# Image rotated Angle :  180 degree
# 2    b14_37.png
# Image rotated Angle :  180 degree
# 3    b8_40.png
# Image rotated Angle :  180 degree
# 4    b8_19.png
# Image rotated Angle :  180 degree
# 5    b8_101.png
# Image rotated Angle :  180 degree
# 6    b14_43.png
# Image rotated Angle :  180 degree
# 7    b8_69.png
# Image rotated Angle :  180 degree
# 8    b14_23.png
# Image rotated Angle :  180 degree
# 9    b8_20.png
# Image rotated Angle :  180 degree
# 10    b14_30.png
# Image rotated Angle :  180 degree
# 11    b8_83.png
# Image rotated Angle :  180 degree
# 12    b14_44.png
# Image rotated Angle :  180 degree
# 13    b14_78.png
# Image rotated Angle :  180 degree
# 14    b8_72.png
# Image rotated Angle :  180 degree
# 15    b8_55.png
# Image rotated Angle :  180 degree
# 16    b8_42.png
# Image rotated Angle :  180 degree
# 17    b8_32.png
# Image rotated Angle :  180 degree
# 18    b14_54.png
# Image rotated Angle :  180 degree
# 19    b8_58.png
# Image rotated Angle :  180 degree
# 20    b8_86.png
# Image rotated Angle :  180 degree
# 21    b8_17.png
# Image rotated Angle :  180 degree
# 22    b8_82.png
# Image rotated Angle :  180 degree
# 23    b14_8.png
# Image rotated Angle :  180 degree
# 24    b14_84.png
# Image rotated Angle :  180 degree
# 25    b14_40.png
# Image rotated Angle :  180 degree
# 26    b8_88.png
# Image rotated Angle :  180 degree
# 27    b14_7.png
# Image rotated Angle :  180 degree
# 28    b8_5.png
# Image rotated Angle :  180 degree
# 29    b8_73.png
# Image rotated Angle :  180 degree
# 30    b8_60.png
# Image rotated Angle :  180 degree
# 31    b8_79.png
# Image rotated Angle :  180 degree
# 32    b14_12.png
# Image rotated Angle :  180 degree
# 33    b14_0.png
# Image rotated Angle :  180 degree
# 34    b8_0.png
# Image rotated Angle :  180 degree
# 35    b8_59.png
# Image rotated Angle :  180 degree
# 36    b8_67.png
# Image rotated Angle :  180 degree
# 37    b8_41.png
# Image rotated Angle :  180 degree
# 38    b8_71.png
# Image rotated Angle :  180 degree
# 39    b14_22.png
# Image rotated Angle :  180 degree
# 40    b8_85.png
# Image rotated Angle :  180 degree
# 41    b14_38.png
# Image rotated Angle :  180 degree
# 42    b14_1.png
# Image rotated Angle :  180 degree
# 43    b8_54.png
# Image rotated Angle :  180 degree
# 44    b8_8.png
# Image rotated Angle :  180 degree
# 45    b8_43.png
# Image rotated Angle :  180 degree
# 46    b14_86.png
# Image rotated Angle :  180 degree
# 47    b8_34.png
# Image rotated Angle :  180 degree
# 48    b14_15.png
# Image rotated Angle :  180 degree
# 49    b8_23.png
# Image rotated Angle :  180 degree
# 50    b14_68.png
# Image rotated Angle :  180 degree
# 51    b14_56.png
# Image rotated Angle :  180 degree
# 52    b8_56.png
# Image rotated Angle :  180 degree
# 53    b8_3.png
# Image rotated Angle :  180 degree
# 54    b14_16.png
# Image rotated Angle :  180 degree
# 55    b8_53.png
# Image rotated Angle :  180 degree
# 56    b14_70.png
# Image rotated Angle :  180 degree
# 57    b8_9.png
# Image rotated Angle :  180 degree
# 58    b14_85.png
# Image rotated Angle :  180 degree
# 59    b8_48.png
# Image rotated Angle :  180 degree
# 60    b14_58.png
# Image rotated Angle :  180 degree
# 61    b14_62.png
# Image rotated Angle :  180 degree
# 62    b8_7.png
# Image rotated Angle :  180 degree
# 63    b14_28.png
# Image rotated Angle :  180 degree
# 64    b8_33.png
# Image rotated Angle :  180 degree
# 65    b14_14.png
# Image rotated Angle :  180 degree
# 66    b14_10.png
# Image rotated Angle :  180 degree
# 67    b8_21.png
# Image rotated Angle :  180 degree
# 68    b14_51.png
# Image rotated Angle :  180 degree
# 69    b8_22.png
# Image rotated Angle :  180 degree
# 70    b8_6.png
# Image rotated Angle :  180 degree
# 71    b8_81.png
# Image rotated Angle :  180 degree
# 72    b14_39.png
# Image rotated Angle :  180 degree
# 73    b8_27.png
# Image rotated Angle :  180 degree
# 74    b14_26.png
# Image rotated Angle :  180 degree
# 75    b14_21.png
# Image rotated Angle :  180 degree
# 76    b14_24.png
# Image rotated Angle :  180 degree
# 77    b14_45.png
# Image rotated Angle :  180 degree
# 78    b8_64.png
# Image rotated Angle :  180 degree
# 79    b8_37.png
# Image rotated Angle :  180 degree
# 80    b8_29.png
# Image rotated Angle :  180 degree
# 81    b8_80.png
# Image rotated Angle :  180 degree
# 82    b8_107.png
# Image rotated Angle :  180 degree
# 83    b8_35.png
# Image rotated Angle :  180 degree
# 84    b14_87.png
# Image rotated Angle :  180 degree
# 85    b8_15.png
# Image rotated Angle :  180 degree
# 86    b14_46.png
# Image rotated Angle :  180 degree
# 87    b8_99.png
# Image rotated Angle :  180 degree
# 88    b8_66.png
# Image rotated Angle :  180 degree
# 89    b8_91.png
# Image rotated Angle :  180 degree
# 90    b8_1.png
# Image rotated Angle :  180 degree
# 91    b8_4.png
# Image rotated Angle :  180 degree
# 92    b14_11.png
# Image rotated Angle :  180 degree
# 93    b14_83.png
# Image rotated Angle :  180 degree
# 94    b8_78.png
# Image rotated Angle :  180 degree
# 95    b8_12.png
# Image rotated Angle :  180 degree
# 96    b8_61.png
# Image rotated Angle :  180 degree
# 97    b8_46.png
# Image rotated Angle :  180 degree
# 98    b8_97.png
# Image rotated Angle :  180 degree
# 99    b8_51.png
# Image rotated Angle :  180 degree
# 100    b8_28.png
# Image rotated Angle :  180 degree
# 101    b8_44.png
# Image rotated Angle :  180 degree
# 102    b8_13.png
# Image rotated Angle :  180 degree
# 103    b14_52.png
# Image rotated Angle :  180 degree
# 104    b8_38.png
# Image rotated Angle :  180 degree
# 105    b8_16.png
# Image rotated Angle :  180 degree
# 106    b8_30.png
# Image rotated Angle :  180 degree
# 107    b8_36.png
# Image rotated Angle :  180 degree
# 108    b8_25.png
# Image rotated Angle :  180 degree
# 109    b8_57.png
# Image rotated Angle :  180 degree
# 110    b8_87.png
# Image rotated Angle :  180 degree
# 111    b8_39.png
# Image rotated Angle :  180 degree
# 112    b8_100.png
# Image rotated Angle :  180 degree
# 113    b14_82.png
# Image rotated Angle :  180 degree
# 114    b14_34.png
# Image rotated Angle :  180 degree
# 115    b14_49.png
# Image rotated Angle :  180 degree
# 116    b14_76.png
# Image rotated Angle :  180 degree
# 117    b14_66.png
# Image rotated Angle :  180 degree
# 118    b14_36.png
# Image rotated Angle :  180 degree
# 119    b8_18.png
# Image rotated Angle :  180 degree
# 120    b8_10.png
# Image rotated Angle :  180 degree
# 121    b8_102.png
# Image rotated Angle :  180 degree
# 122    b14_75.png
# Image rotated Angle :  180 degree
# 123    b8_108.png
# Image rotated Angle :  180 degree
# 124    b8_70.png
# Image rotated Angle :  180 degree
# 125    b14_6.png
# Image rotated Angle :  180 degree
# 126    b14_29.png
# Image rotated Angle :  180 degree
# 127    b14_79.png
# Image rotated Angle :  180 degree
# 128    b8_77.png
# Image rotated Angle :  180 degree
# 129    b8_47.png
# Image rotated Angle :  180 degree
# 130    b14_55.png
# Image rotated Angle :  180 degree
# 131    b14_5.png
# Image rotated Angle :  180 degree
# 132    b8_103.png
# Image rotated Angle :  180 degree
# 133    b14_31.png
# Image rotated Angle :  180 degree
# 134    b14_72.png
# Image rotated Angle :  180 degree
# 135    b8_76.png
# Image rotated Angle :  180 degree
# 136    b8_62.png
# Image rotated Angle :  180 degree
# 137    b8_26.png
# Image rotated Angle :  180 degree
# 138    b8_90.png
# Image rotated Angle :  180 degree
# 139    b8_105.png
# Image rotated Angle :  180 degree
# 140    b8_49.png
# Image rotated Angle :  180 degree
# 141    b8_11.png
# Image rotated Angle :  180 degree
# 142    b14_50.png
# Image rotated Angle :  180 degree
# 143    b14_35.png
# Image rotated Angle :  180 degree
# 144    b8_93.png
# Image rotated Angle :  180 degree
# 145    b14_74.png
# Image rotated Angle :  180 degree
# 146    b8_92.png
# Image rotated Angle :  180 degree
# 147    b8_52.png
# Image rotated Angle :  180 degree
# 148    b14_9.png
# Image rotated Angle :  180 degree
# 149    b14_17.png
# Image rotated Angle :  180 degree
# 150    b14_81.png
# Image rotated Angle :  180 degree
# 151    b8_104.png
# Image rotated Angle :  180 degree
# 152    b8_2.png
# Image rotated Angle :  180 degree
# 153    b8_89.png
# Image rotated Angle :  180 degree
# 154    b14_18.png
# Image rotated Angle :  180 degree
# 155    b14_48.png
# Image rotated Angle :  180 degree
# 156    b14_13.png
# Image rotated Angle :  180 degree
# 157    b8_74.png
# Image rotated Angle :  180 degree
# 158    b8_45.png
# Image rotated Angle :  180 degree
# 159    b8_50.png
# Image rotated Angle :  180 degree
# 160    b8_31.png
# Image rotated Angle :  180 degree
# 161    b14_2.png
# Image rotated Angle :  180 degree
# 162    b8_75.png
# Image rotated Angle :  180 degree
# 163    b14_25.png
# Image rotated Angle :  180 degree
# 164    b14_4.png
# Image rotated Angle :  180 degree
# 165    b14_60.png
# Image rotated Angle :  180 degree
# 166    b8_24.png
# Image rotated Angle :  180 degree
# 167    b14_27.png
# Image rotated Angle :  180 degree
# 168    b14_64.png
# Image rotated Angle :  180 degree
# 169    b8_68.png
# Image rotated Angle :  180 degree
# 170    b14_42.png
# Image rotated Angle :  180 degree
# 171    b8_84.png
# Image rotated Angle :  180 degree
# 172    b14_80.png
# Image rotated Angle :  180 degree
# 173    b8_106.png
# Image rotated Angle :  180 degree
# 174    b8_65.png
# Image rotated Angle :  180 degree
# 175    b14_3.png
# Image rotated Angle :  180 degree

# %%
path = '/home/vimalkumar/Downloads/stewart degrees test/test/90 test'
count = 1
for i in os.listdir(path):
    print(count ,'  ',i)
    count += 1
    img = image.load_img(os.path.join(path,i), 
                         target_size=(224,224))
    #     plt.figure(figsize=(15,20))
    #     plt.imshow(img)
    plt.show()

    x = image.img_to_array(img)
    x = x/255
    x = np.expand_dims(x,axis=0)
    images = np.vstack([x])
    val = model.predict(images)
    #print(val)

    a=np.argmax(val,axis=1)
    #print(a)
    print('Image rotated Angle : ',dic[a[0]])
# Out:
# 1    b17_39.png
# Image rotated Angle :  90 degree
# 2    b17_40.png
# Image rotated Angle :  270 degree
# 3    b17_13.png
# Image rotated Angle :  180 degree
# 4    b17_23.png
# Image rotated Angle :  90 degree
# 5    b17_67.png
# Image rotated Angle :  90 degree
# 6    b17_45.png
# Image rotated Angle :  90 degree
# 7    b17_28.png
# Image rotated Angle :  90 degree
# 8    b17_53.png
# Image rotated Angle :  90 degree
# 9    b17_49.png
# Image rotated Angle :  90 degree
# 10    b17_48.png
# Image rotated Angle :  90 degree
# 11    b17_42.png
# Image rotated Angle :  270 degree
# 12    b17_87.png
# Image rotated Angle :  0 degree
# 13    b17_25.png
# Image rotated Angle :  270 degree
# 14    b17_58.png
# Image rotated Angle :  90 degree
# 15    b17_2.png
# Image rotated Angle :  90 degree
# 16    b17_81.png
# Image rotated Angle :  90 degree
# 17    b17_5.png
# Image rotated Angle :  90 degree
# 18    b17_24.png
# Image rotated Angle :  90 degree
# 19    b17_18.png
# Image rotated Angle :  90 degree
# 20    b17_50.png
# Image rotated Angle :  90 degree
# 21    b17_75.png
# Image rotated Angle :  90 degree
# 22    b17_7.png
# Image rotated Angle :  270 degree
# 23    b17_68.png
# Image rotated Angle :  90 degree
# 24    b17_62.png
# Image rotated Angle :  90 degree
# 25    b17_95.png
# Image rotated Angle :  180 degree
# 26    b17_34.png
# Image rotated Angle :  90 degree
# 27    b17_82.png
# Image rotated Angle :  90 degree
# 28    b17_21.png
# Image rotated Angle :  90 degree
# 29    b17_65.png
# Image rotated Angle :  90 degree
# 30    b17_96.png
# Image rotated Angle :  270 degree
# 31    b17_90.png
# Image rotated Angle :  90 degree
# 32    b17_103.png
# Image rotated Angle :  90 degree
# 33    b17_71.png
# Image rotated Angle :  90 degree
# 34    b17_57.png
# Image rotated Angle :  90 degree
# 35    b17_1.png
# Image rotated Angle :  90 degree
# 36    b17_41.png
# Image rotated Angle :  90 degree
# 37    b17_51.png
# Image rotated Angle :  90 degree
# 38    b17_19.png
# Image rotated Angle :  90 degree
# 39    b17_97.png
# Image rotated Angle :  270 degree
# 40    b17_98.png
# Image rotated Angle :  270 degree
# 41    b17_66.png
# Image rotated Angle :  90 degree
# 42    b17_17.png
# Image rotated Angle :  90 degree
# 43    b17_86.png
# Image rotated Angle :  90 degree
# 44    b17_100.png
# Image rotated Angle :  90 degree
# 45    b17_59.png
# Image rotated Angle :  90 degree
# 46    b17_89.png
# Image rotated Angle :  0 degree
# 47    b17_56.png
# Image rotated Angle :  270 degree
# 48    b17_44.png
# Image rotated Angle :  180 degree
# 49    b17_47.png
# Image rotated Angle :  90 degree
# 50    b17_69.png
# Image rotated Angle :  90 degree
# 51    b17_37.png
# Image rotated Angle :  90 degree
# 52    b17_70.png
# Image rotated Angle :  90 degree
# 53    b17_78.png
# Image rotated Angle :  90 degree
# 54    b17_104.png
# Image rotated Angle :  90 degree
# 55    b17_4.png
# Image rotated Angle :  90 degree
# 56    b17_33.png
# Image rotated Angle :  90 degree
# 57    b17_92.png
# Image rotated Angle :  90 degree
# 58    b17_79.png
# Image rotated Angle :  270 degree
# 59    b17_84.png
# Image rotated Angle :  0 degree
# 60    b17_11.png
# Image rotated Angle :  90 degree
# 61    b17_55.png
# Image rotated Angle :  90 degree
# 62    b17_61.png
# Image rotated Angle :  90 degree
# 63    b17_0.png
# Image rotated Angle :  90 degree
# 64    b17_46.png
# Image rotated Angle :  90 degree
# 65    b17_60.png
# Image rotated Angle :  90 degree
# 66    b17_88.png
# Image rotated Angle :  0 degree
# 67    b17_3.png
# Image rotated Angle :  90 degree
# 68    b17_6.png
# Image rotated Angle :  90 degree
# 69    b17_93.png
# Image rotated Angle :  90 degree
# 70    b17_52.png
# Image rotated Angle :  90 degree
# 71    b17_74.png
# Image rotated Angle :  90 degree
# 72    b17_16.png
# Image rotated Angle :  90 degree
# 73    b17_94.png
# Image rotated Angle :  90 degree
# 74    b17_8.png
# Image rotated Angle :  90 degree
# 75    b17_91.png
# Image rotated Angle :  0 degree
# 76    b17_10.png
# Image rotated Angle :  90 degree
# 77    b17_99.png
# Image rotated Angle :  270 degree
# 78    b17_22.png
# Image rotated Angle :  90 degree
# 79    b17_101.png
# Image rotated Angle :  90 degree
# 80    b17_77.png
# Image rotated Angle :  90 degree
# 81    b17_26.png
# Image rotated Angle :  90 degree
# 82    b17_54.png
# Image rotated Angle :  90 degree
# 83    b17_85.png
# Image rotated Angle :  0 degree
# 84    b17_36.png
# Image rotated Angle :  90 degree
# 85    b17_14.png
# Image rotated Angle :  90 degree
# 86    b17_15.png
# Image rotated Angle :  90 degree
# 87    b17_38.png
# Image rotated Angle :  270 degree
# 88    b17_43.png
# Image rotated Angle :  90 degree
# 89    b17_35.png
# Image rotated Angle :  90 degree
# 90    b17_64.png
# Image rotated Angle :  90 degree
# 91    b17_29.png
# Image rotated Angle :  90 degree
# 92    b17_73.png
# Image rotated Angle :  90 degree
# 93    b17_83.png
# Image rotated Angle :  0 degree
# 94    b17_72.png
# Image rotated Angle :  90 degree
# 95    b17_9.png
# Image rotated Angle :  90 degree
# 96    b17_27.png
# Image rotated Angle :  90 degree
# 97    b17_20.png
# Image rotated Angle :  90 degree
# 98    b17_63.png
# Image rotated Angle :  90 degree
# 99    b17_80.png
# Image rotated Angle :  90 degree
# 100    b17_76.png
# Image rotated Angle :  90 degree
# 101    b17_12.png
# Image rotated Angle :  90 degree
# 102    b17_32.png
# Image rotated Angle :  90 degree
# 103    b17_31.png
# Image rotated Angle :  90 degree
# 104    b17_102.png
# Image rotated Angle :  90 degree

# %%
path = '/home/vimalkumar/Downloads/stewart degrees test/test/0 test'
count = 1
for i in os.listdir(path):
    print(count ,'  ',i)
    count += 1
    img = image.load_img(os.path.join(path,i), 
                         target_size=(224,224))
    #     plt.figure(figsize=(15,20))
    #     plt.imshow(img)
    plt.show()

    x = image.img_to_array(img)
    x = x/255
    x = np.expand_dims(x,axis=0)
    images = np.vstack([x])
    val = model.predict(images)
    #print(val)

    a=np.argmax(val,axis=1)
    #print(a)
    print('Image rotated Angle : ',dic[a[0]])
# Out:
# 1    b17_2.jpeg
# Image rotated Angle :  0 degree
# 2    b17_13.jpeg
# Image rotated Angle :  90 degree
# 3    b17_33.jpeg
# Image rotated Angle :  0 degree
# 4    b17_11.jpeg
# Image rotated Angle :  0 degree
# 5    b17_18.jpeg
# Image rotated Angle :  0 degree
# 6    b17_89.jpeg
# Image rotated Angle :  0 degree
# 7    b17_19.jpeg
# Image rotated Angle :  0 degree
# 8    b17_31.jpeg
# Image rotated Angle :  0 degree
# 9    b17_87.jpeg
# Image rotated Angle :  0 degree
# 10    b17_84.jpeg
# Image rotated Angle :  0 degree
# 11    b17_24.jpeg
# Image rotated Angle :  0 degree
# 12    b17_86.jpeg
# Image rotated Angle :  0 degree
# 13    b17_35.jpeg
# Image rotated Angle :  0 degree
# 14    b17_1.jpeg
# Image rotated Angle :  0 degree
# 15    b17_8.jpeg
# Image rotated Angle :  0 degree
# 16    b17_9.jpeg
# Image rotated Angle :  0 degree
# 17    b17_3.jpeg
# Image rotated Angle :  0 degree
# 18    b17_27.jpeg
# Image rotated Angle :  0 degree
# 19    b17_34.jpeg
# Image rotated Angle :  0 degree
# 20    b17_85.jpeg
# Image rotated Angle :  0 degree
# 21    b17_6.jpeg
# Image rotated Angle :  0 degree
# 22    b17_10.jpeg
# Image rotated Angle :  0 degree
# 23    b17_26.jpeg
# Image rotated Angle :  0 degree
# 24    b17_4.jpeg
# Image rotated Angle :  0 degree
# 25    b17_21.jpeg
# Image rotated Angle :  0 degree
# 26    b17_88.jpeg
# Image rotated Angle :  0 degree
# 27    b17_22.jpeg
# Image rotated Angle :  0 degree
# 28    b17_15.jpeg
# Image rotated Angle :  0 degree
# 29    b17_29.jpeg
# Image rotated Angle :  0 degree
# 30    b17_82.jpeg
# Image rotated Angle :  0 degree
# 31    b17_28.jpeg
# Image rotated Angle :  0 degree
# 32    b17_12.jpeg
# Image rotated Angle :  0 degree
# 33    b17_16.jpeg
# Image rotated Angle :  0 degree
# 34    b17_14.jpeg
# Image rotated Angle :  0 degree
# 35    b17_20.jpeg
# Image rotated Angle :  0 degree
# 36    b17_23.jpeg
# Image rotated Angle :  0 degree
# 37    b17_7.jpeg
# Image rotated Angle :  180 degree
# 38    b17_0.jpeg
# Image rotated Angle :  0 degree
# 39    b17_36.jpeg
# Image rotated Angle :  0 degree
# 40    b17_25.jpeg
# Image rotated Angle :  180 degree
# 41    b17_83.jpeg
# Image rotated Angle :  0 degree
# 42    b17_17.jpeg
# Image rotated Angle :  0 degree
# 43    b17_5.jpeg
# Image rotated Angle :  0 degree
# 44    b17_32.jpeg
# Image rotated Angle :  0 degree

# %%
path = '/home/vimalkumar/Downloads/images/Batch 9/1052.jpeg'
predict_image(path)
# Out:
# [[0.26722032 0.6395958  0.09318382]]
# Image rotated Angle :  180
