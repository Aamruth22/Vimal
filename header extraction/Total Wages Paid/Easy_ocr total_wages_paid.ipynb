# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import warnings
warnings.filterwarnings("ignore")

reader = easyocr.Reader(['en'],gpu = False)
image = cv2.imread('/home/vimalkumar.s/Downloads/0101685000.tif')
res = image.copy()
width = res.shape[1]
height = res.shape[0]
wi = width * 0.95
he = height * 0.3
w = int(wi)
h = int(he)
y = 0
x1 = w * 0.45
x = int(x1)
crop = res[y:y+h, x:x+w]
im = crop.copy()
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
r_easy_ocr=reader.readtext(thresh,detail=0)
print(r_easy_ocr)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ['EAU4', 'MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', 'BLOCK', '01-01685-0-00', '2020', '(DO NOT', 'USE)', 'CALENDAR QUARTER', 'Date Paid', 'Ist', '2nd', '3rd', '4th', 'MUST HAVE AMOUNTS IN 4,5, & 6 EVEN IF ZERO', 'TOTAL WAGES PAID', '330483 95', '5 WAGES PAID IN EXCESS OF', '11500 00', 'PER WORKER', 'PER YEAR (See Instruction Sheet)', '223644 75', '6 TAXABLE WAGES', '(Item 4 Minus Item 5)', '106839 20']

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import warnings
warnings.filterwarnings("ignore")

reader = easyocr.Reader(['en'],gpu = False)
image = cv2.imread('/home/vimalkumar.s/Downloads/0113861000.tif')
res = image.copy()
width = res.shape[1]
height = res.shape[0]
wi = width * 0.95
he = height * 0.3
w = int(wi)
h = int(he)
y = 0
x1 = w * 0.45
x = int(x1)
crop = res[y:y+h, x:x+w]
im = crop.copy()
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
r_easy_ocr=reader.readtext(thresh,detail=0)
print(r_easy_ocr)
special_chars = [',','.',' ','  ',';', ':', '!', "*"]
z = []
for a in r_easy_ocr:
    for b in special_chars:
        if b in a:
            z.append(a)
#print(z)

out_list = [''.join(filter(str.isalnum, string)) for string in z]

#print(out_list)

y=[]
for i in out_list:
    if (i.isdigit()):
        y.append(int(i))
#print(y)
print('TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ['EAUA', 'MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIt', 'BLOCK', '01-13861-0-00', '2020', '(DO NOT', 'use)', '3 CALENDAR QUARTER', 'Date Paid ', 'Ist', 'X', '2nd', '3rd', '4th', 'MUST HAVE AMOUNT IN 4, 5, & 6 EVEN IF "Zero"', '4 TOTAL WAGES PAID', '159,130', '34', '5 WAGES PAID IN EXCESS OF', '11,500', '00', 'PER WORKER', 'PER YEAR (See Instruction Sheet}', '6 TAXABLE WAGES', '159,130', '34', 'Item 4 Minus Item 5']
# TOTAL WAGES PAID 159130

# %%
for i in r_easy_ocr:
    if ',' in i:
        #print(i)
        index_1 = r_easy_ocr.index(i)
        index_2 = r_easy_ocr.index(i)+2
        #print(r_easy_ocr.index(i))
        #print(r_easy_ocr.index(i)+2)
        check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
        if check_num.isdigit():
            r_easy_ocr[index_1 : index_2] = [''.join(r_easy_ocr[index_1 : index_2])]
        print(r_easy_ocr)
# Out:
# ['EAUA', 'MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIt', 'BLOCK', '01-13861-0-00', '2020', '(DO NOT', 'use)', '3 CALENDAR QUARTER', 'Date Paid ', 'Ist', 'X', '2nd', '3rd', '4th', 'MUST HAVE AMOUNT IN 4, 5, & 6 EVEN IF "Zero"', '4 TOTAL WAGES PAID', '159,130', '34', '5 WAGES PAID IN EXCESS OF', '11,500', '00', 'PER WORKER', 'PER YEAR (See Instruction Sheet}', '6 TAXABLE WAGES', '159,130', '34', 'Item 4 Minus Item 5']
# ['EAUA', 'MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIt', 'BLOCK', '01-13861-0-00', '2020', '(DO NOT', 'use)', '3 CALENDAR QUARTER', 'Date Paid ', 'Ist', 'X', '2nd', '3rd', '4th', 'MUST HAVE AMOUNT IN 4, 5, & 6 EVEN IF "Zero"', '4 TOTAL WAGES PAID', '159,13034', '5 WAGES PAID IN EXCESS OF', '11,500', '00', 'PER WORKER', 'PER YEAR (See Instruction Sheet}', '6 TAXABLE WAGES', '159,130', '34', 'Item 4 Minus Item 5']
# ...

# %%
for i in r_easy_ocr:
    if ',' in i:
        #print(i)
        index_1 = r_easy_ocr.index(i)
        index_2 = r_easy_ocr.index(i)+1
        #print(r_easy_ocr.index(i))
        #print(r_easy_ocr.index(i)+2)
        check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
        if check_num.isdigit():
            r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
print(r_easy_ocr)
# Out:
# ['EAUA', 'MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIt', 'BLOCK', '01-13861-0-00', '2020', '(DO NOT', 'use)', '3 CALENDAR QUARTER', 'Date Paid ', 'Ist', 'X', '2nd', '3rd', '4th', 'MUST HAVE AMOUNT IN 4, 5, & 6 EVEN IF "Zero"', '4 TOTAL WAGES PAID', '159,13034', '5 WAGES PAID IN EXCESS OF', '11,50000', 'PER WORKER', 'PER YEAR (See Instruction Sheet}', '6 TAXABLE WAGES', '159,13034', 'Item 4 Minus Item 5']

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import warnings
warnings.filterwarnings("ignore")

reader = easyocr.Reader(['en'],gpu = False)
image = cv2.imread('/home/vimalkumar.s/Documents/Good Files/0113861000.tif')
res = image.copy()
width = res.shape[1]
height = res.shape[0]
wi = width * 0.95
he = height * 0.3
w = int(wi)
h = int(he)
y = 0
x1 = w * 0.45
x = int(x1)
crop = res[y:y+h, x:x+w]
im = crop.copy()
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
r_easy_ocr=reader.readtext(thresh,detail=0)
print(r_easy_ocr)

final = []
for i in r_easy_ocr:
    if ',' in i:
        #print(i)
        index_1 = r_easy_ocr.index(i)
        index_2 = r_easy_ocr.index(i)+1
        #print(r_easy_ocr.index(i))
        check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
        if check_num.isdigit():
            r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
        final.append(r_easy_ocr)
print(final[0])

special_chars = [',','.',' ','  ',';', ':', '!', "*"]
z = []
for a in final[0]:
    for b in special_chars:
        if b in a:
            z.append(a)
#print(z)

out_list = [''.join(filter(str.isalnum, string)) for string in z]
print(out_list)

y=[]
for i in out_list:
    if (i.isdigit()):
        y.append(int(i))
print(y)
print('TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ['EAUA', 'MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIt', 'BLOCK', '01-13861-0-00', '2020', '(DO NOT', 'use)', '3 CALENDAR QUARTER', 'Date Paid ', 'Ist', 'X', '2nd', '3rd', '4th', 'MUST HAVE AMOUNT IN 4, 5, & 6 EVEN IF "Zero"', '4 TOTAL WAGES PAID', '159,130', '34', '5 WAGES PAID IN EXCESS OF', '11,500', '00', 'PER WORKER', 'PER YEAR (See Instruction Sheet}', '6 TAXABLE WAGES', '159,130', '34', 'Item 4 Minus Item 5']
# ['EAUA', 'MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIt', 'BLOCK', '01-13861-0-00', '2020', '(DO NOT', 'use)', '3 CALENDAR QUARTER', 'Date Paid ', 'Ist', 'X', '2nd', '3rd', '4th', 'MUST HAVE AMOUNT IN 4, 5, & 6 EVEN IF "Zero"', '4 TOTAL WAGES PAID', '159,13034', '5 WAGES PAID IN EXCESS OF', '11,50000', 'PER WORKER', 'PER YEAR (See Instruction Sheet}', '6 TAXABLE WAGES', '159,13034', 'Item 4 Minus Item 5']
# ...

# %%
final[0]
# Out:
# ['EAUA',
#  'MO EMPLOYER ACCOUNT NO',
#  'YEAR',
#  'AUDIt',
#  'BLOCK',
#  '01-13861-0-00',
#  '2020',
#  '(DO NOT',
#  'use)',
#  '3 CALENDAR QUARTER',
#  'Date Paid ',
#  'Ist',
#  'X',
#  '2nd',
#  '3rd',
#  '4th',
#  'MUST HAVE AMOUNT IN 4, 5, & 6 EVEN IF "Zero"',
#  '4 TOTAL WAGES PAID',
#  '159,13034',
#  '5 WAGES PAID IN EXCESS OF',
#  '11,50000',
#  'PER WORKER',
#  'PER YEAR (See Instruction Sheet}',
#  '6 TAXABLE WAGES',
#  '159,13034',
#  'Item 4 Minus Item 5']

# %%
final = []
for i in r_easy_ocr:
    if ',' in i:
        #print(i)
        index_1 = r_easy_ocr.index(i)
        index_2 = r_easy_ocr.index(i)+1
        #print(r_easy_ocr.index(i))
        check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
        if check_num.isdigit():
            r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
            final.append(r_easy_ocr)
print(final)
special_chars = [',','.',' ','  ',';', ':', '!', "*"]
z = []
for a in final[0]:
    for b in special_chars:
        if b in a:
            z.append(a)
#print(z)

out_list = [''.join(filter(str.isalnum, string)) for string in z]

#print(out_list)

y=[]
for i in out_list:
    if (i.isdigit()):
        y.append(int(i))
#print(y)
print('TOTAL WAGES PAID',max(y))

# %%
special_chars = [',','.',' ','  ',';', ':', '!', "*"]
for a in r_easy_ocr:
    for b in special_chars:
        if b in a:
            print(a)
# Out:
# 2 MO EMPLOYER ACCOUNT NO
# (DO NOT
# 3 CALENDAR QUARTER
# Date Paid
# MUST HAVE AMOUNTS IN 4,5, & 6,EVEN IF ZERO
# MUST HAVE AMOUNTS IN 4,5, & 6,EVEN IF ZERO
# TOTAL WAGES PAID
# 15,395
# 5 WAGES PAID IN EXCESS OF
# 11,500
# 00 PER WORKER
# PER YEAR (Sce [nstruction Shecl)
# 6 TAXABLE WAGES
# 15 295

# %%
special_chars = [',','.',' ','  ',';', ':', '!', "*"]
z = []
for a in r_easy_ocr:
    for b in special_chars:
        if b in a:
            z.append(a)
print(z)
# Out:
# ['2 MO EMPLOYER ACCOUNT NO', '(DO NOT', '3 CALENDAR QUARTER', 'Date Paid', 'MUST HAVE AMOUNTS IN 4,5, & 6,EVEN IF ZERO', 'MUST HAVE AMOUNTS IN 4,5, & 6,EVEN IF ZERO', 'TOTAL WAGES PAID', '15,395', '5 WAGES PAID IN EXCESS OF', '11,500', '00 PER WORKER', 'PER YEAR (Sce [nstruction Shecl)', '6 TAXABLE WAGES', '15 295']

# %%
for i in r_easy_ocr:
    if ',' in i:
        print(i)
        index_1 = r_easy_ocr.index(i)
        #print(index_1)
        index_2 = (r_easy_ocr.index(i)+1)
        #print(index_2)
        #print(r_easy_ocr[index_2])
        if r_easy_ocr[index_2].isdigit():
            r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
            #print(r_easy_ocr[index_1 : index_2])
# Out:
# MUST HAVE AMOUNTS IN 4,5, & 6 EVEN IF ZERO
# 9, 000 _
# 11,500 00

# %%
c = ['214,22','32','22546']
c
# Out:
# ['214,22', '32', '22546']

# %%
for i in c:
    if ',' in i:
        print(i)
        index_1 = c.index(i)
        print(index_1)
        if c[c.index(i)+1].isdigit():
            print
        #print(c.index(i))
        #print(c[c.index(i)+1])
# Out:
# 214,22
# 0

# %%
for i in c:
    if ',' in i:
        print(i)
        index_1 = c.index(i)
        print(index_1)
        index_2 = (c.index(i)+1)
        print(index_2)
        print(c[index_2])
        if c[index_2].isdigit():
            c[index_1 : index_2+1] = [''.join(c[index_1 : index_2+1])]
            print(c[index_1 : index_2])
# Out:
# 214,22
# 0
# 1
# 32
# ['214,2232']

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import warnings
warnings.filterwarnings("ignore")

reader = easyocr.Reader(['en'],gpu = False)
path = '/home/vimalkumar.s/Documents/Good Files/cells'
for i in os.listdir(path):
    image = cv2.imread(os.path.join(path,i))
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
#print(r_easy_ocr)
special_chars = [',','.',' ','  ',';', ':', '!', "*"]
z = []
for a in r_easy_ocr:
    for b in special_chars:
        if b in a:
            z.append(a)
#print(z)

out_list = [''.join(filter(str.isalnum, string)) for string in z]

#print(out_list)

y=[]
for i in out_list:
    if (i.isdigit()):
        y.append(int(i))
#print(y)
print('TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# TOTAL WAGES PAID 1896509

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import warnings
warnings.filterwarnings("ignore")

reader = easyocr.Reader(['en'],gpu = False)
image = cv2.imread('/home/vimalkumar.s/Documents/Good Files/0497041000.tif')
res = image.copy()
width = res.shape[1]
height = res.shape[0]
wi = width * 0.95
he = height * 0.3
w = int(wi)
h = int(he)
y = 0
x1 = w * 0.45
x = int(x1)
crop = res[y:y+h, x:x+w]
im = crop.copy()
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
r_easy_ocr=reader.readtext(thresh,detail=0)
r_easy_ocr.append('aaaa')
print(r_easy_ocr)
sym = [',',['.']]
final = []
for i in r_easy_ocr:
    for j in sym 
        if ' ' in i:
            #print(i)
            index_1 = r_easy_ocr.index(i)
            index_2 = r_easy_ocr.index(i)+1
            #print(r_easy_ocr.index(i))
            check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
            if check_num.isdigit():
                r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
            final.append(r_easy_ocr)
print(final[0])

special_chars = [',','.',' ','  ',';', ':', '!', "*"]
z = []
for a in final[0]:
    for b in special_chars:
        if b in a:
            z.append(a)
#print(z)

out_list = [''.join(filter(str.isalnum, string)) for string in z]
#print(out_list)

y=[]
for i in out_list:
    if (i.isdigit()):
        y.append(int(i))
#print(y)
print('TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ['2', 'MISSOURI EMPLOYER ACCOUNT NO', 'AuDit BLOCK', '04-97041-0-00', '(DO NOT USE)', 'CALENDAR QUARTER', 'Date', '1/20', 'Paid', 'MUST HAVE AMOUNT IN 4, 5, & 6 EVEN IF "ZERO"', "'4", 'TOTAL WAGES PAID', '11500', '00', '"5', 'WAGES PAIDAIN-EXCESS', 'OF', '1i500 , 00', 'PER WORKER PER YEAR', '(See instructions)', '0', '001', '6', 'TAXABLE WAGES', 'Item 4 Minus Iter', '11500', '00', 'TAXES DUE', 'Dua', 'Multiply Item 6 by Your', 'aaaa']
# ['2', 'MISSOURI EMPLOYER ACCOUNT NO', 'AuDit BLOCK', '04-97041-0-00', '(DO NOT USE)', 'CALENDAR QUARTER', 'Date', '1/20', 'Paid', 'MUST HAVE AMOUNT IN 4, 5, & 6 EVEN IF "ZERO"', "'4", 'TOTAL WAGES PAID11500', '00', '"5', 'WAGES PAIDAIN-EXCESS', 'OF', '1i500 , 00', 'PER WORKER PER YEAR', '(See instructions)0', '001', '6', 'TAXABLE WAGES', 'Item 4 Minus Iter11500', '00', 'TAXES DUE', 'Dua', 'Multiply Item 6 by Your', 'aaaa']
# ...

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import warnings
warnings.filterwarnings("ignore")

reader = easyocr.Reader(['en'],gpu = False)
image = cv2.imread('/home/vimalkumar.s/Documents/Good Files/0100931000.tif')
res = image.copy()
width = res.shape[1]
height = res.shape[0]
wi = width * 0.95
he = height * 0.3
w = int(wi)
h = int(he)
y = 0
x1 = w * 0.45
x = int(x1)
crop = res[y:y+h, x:x+w]
im = crop.copy()
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
r_easy_ocr=reader.readtext(thresh,detail=0)
r_easy_ocr.append('aaaa')
print(r_easy_ocr)

final = []
for i in r_easy_ocr:
    if ',' in i:
        #print(i)
        index_1 = r_easy_ocr.index(i)
        index_2 = r_easy_ocr.index(i)+1
        #print(r_easy_ocr.index(i))
        check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
        if check_num.isdigit():
            r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
        final.append(r_easy_ocr)
print(final[0])

special_chars = [',','.',' ','  ',';', ':', '!', "*"]
z = []
for a in final[0]:
    for b in special_chars:
        if b in a:
            z.append(a)
#print(z)

out_list = [''.join(filter(str.isalnum, string)) for string in z]
#print(out_list)

y=[]
for i in out_list:
    if (i.isdigit()):
        y.append(int(i))
#print(y)
print('TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ['ITY', '2 MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', '(DO NOT', '01-00931-0-00', '2020', 'USE)', '3 CALENDAR QUARTER', 'Date Paid', 'Ist', 'X', '2nd', '3rd', '4th', 'MUST HAVE AMOUNTS IN 4,5,& 6,EVEN IF ZERO', 'TOTAL WAGES PAID', '2, 624.23', '93', 'WAGES PAID IN EXCESS OF', '11,500', '00 PER WORKER', 'PER YEAR (See Instrucuon Sheet)', '0', '00', '6 TAXABLE WAGES', '(Item 4 Minus Item 5)', '2   624', '23', 'aaaa']
# ['ITY', '2 MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', '(DO NOT', '01-00931-0-00', '2020', 'USE)', '3 CALENDAR QUARTER', 'Date Paid', 'Ist', 'X', '2nd', '3rd', '4th', 'MUST HAVE AMOUNTS IN 4,5,& 6,EVEN IF ZERO', 'TOTAL WAGES PAID', '2, 624.2393', 'WAGES PAID IN EXCESS OF', '11,500', '00 PER WORKER', 'PER YEAR (See Instrucuon Sheet)', '0', '00', '6 TAXABLE WAGES', '(Item 4 Minus Item 5)', '2   624', '23', 'aaaa']
# TOTAL WAGES PAID 26242393

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import os
import warnings
warnings.filterwarnings("ignore")


reader = easyocr.Reader(['en'],gpu = False)
path = '/home/vimalkumar.s/Documents/100 files/Good Doc/test'
for img in os.listdir(path):
    image = cv2.imread(os.path.join(path,img))
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
    r_easy_ocr.append('aaaa')

#print(r_easy_ocr)

    final = []
    for i in r_easy_ocr:
        if ',' in i:
            #print(i)
            index_1 = r_easy_ocr.index(i)
            index_2 = r_easy_ocr.index(i)+1
            #print(r_easy_ocr.index(i))
            check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
            if check_num.isdigit():
                r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
            final.append(r_easy_ocr)
    #print(final[0])

    special_chars = [',','.',' ','  ',';', ':', '!', "*"]
    z = []
    for a in final[0]:
        for b in special_chars:
            if b in a:
                z.append(a)
    #print(z)

    out_list = [''.join(filter(str.isalnum, string)) for string in z]
    #print(out_list)

    y=[]
    for i in out_list:
        if (i.isdigit()):
            y.append(int(i))
#print(y)
    #l = [11500,115000,1150000]
    #for j in l:
        #if j in y:
            #y.remove(j)
    #print(y)
    print('TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# TOTAL WAGES PAID 90754
# TOTAL WAGES PAID 11421015
# TOTAL WAGES PAID 1150000
# TOTAL WAGES PAID 42034488
# TOTAL WAGES PAID 1332100
# TOTAL WAGES PAID 3000000
# TOTAL WAGES PAID 1150000
# TOTAL WAGES PAID 6019256
# TOTAL WAGES PAID 3239901
# TOTAL WAGES PAID 19035118
# TOTAL WAGES PAID 450000
# TOTAL WAGES PAID 16608439
# TOTAL WAGES PAID 12854493
# TOTAL WAGES PAID 220899
# TOTAL WAGES PAID 3610000
# TOTAL WAGES PAID 1715246
# TOTAL WAGES PAID 9365312
# TOTAL WAGES PAID 1150000
# TOTAL WAGES PAID 2615300
# TOTAL WAGES PAID 18000028
# TOTAL WAGES PAID 2868068
# TOTAL WAGES PAID 3163933
# TOTAL WAGES PAID 2370975
# TOTAL WAGES PAID 278100
# TOTAL WAGES PAID 1919870
# TOTAL WAGES PAID 49336484
# TOTAL WAGES PAID 1200000
# TOTAL WAGES PAID 2113550
# TOTAL WAGES PAID 1150000
# TOTAL WAGES PAID 7930837
# TOTAL WAGES PAID 150000
# TOTAL WAGES PAID 2250000
# TOTAL WAGES PAID 801000
# TOTAL WAGES PAID 1200000
# ...

# %%
0110182000.tif

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import warnings
warnings.filterwarnings("ignore")

reader = easyocr.Reader(['en'],gpu = False)
image = cv2.imread('/home/vimalkumar.s/Documents/100 files/Bad doc/test/0110182000.tif')
res = image.copy()
width = res.shape[1]
height = res.shape[0]
wi = width * 0.95
he = height * 0.3
w = int(wi)
h = int(he)
y = 0
x1 = w * 0.45
x = int(x1)
crop = res[y:y+h, x:x+w]
im = crop.copy()
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
r_easy_ocr=reader.readtext(thresh,detail=0)
r_easy_ocr.append('aaaa')
print(r_easy_ocr)
sym = [',','.',' ']
final = []
for i in r_easy_ocr:
    for j in sym:
        if j in i:
            #print(i)
            index_1 = r_easy_ocr.index(i)
            index_2 = r_easy_ocr.index(i)+1
            #print(r_easy_ocr.index(i))
            check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
            if check_num.isdigit():
                r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
            final.append(r_easy_ocr)
print(final[0])

special_chars = [',','.',' ','  ',';', ':', '!', "*"]
z = []
for a in final[0]:
    for b in special_chars:
        if b in a:
            z.append(a)
#print(z)

out_list = [''.join(filter(str.isalnum, string)) for string in z]
#print(out_list)

y=[]
for i in out_list:
    if (i.isdigit()):
        y.append(int(i))
#print(y)
print('TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ['2', 'MISSOURI EMPLOYER ACCOUNT NO', 'Audit BLOCK', '01-10182-0-00_', '(Do NOT USE)', 'CALENOAR QUARTER', 'Date', 'Paid', '3/20', 'MuST HAVE AMOUNT IN 4,5, &6 EVENIF\'ZERO"', '#4', 'TOTAL WAGES PAID_', '69976', '40]', '#5', 'WACES PAID IN EXCESS', 'OF', '11500', '00', 'PER WORKER PER YEAR', '(See instructions)', '29254', '62', '6', 'TAXABLE WAGES', 'Item 4 Minus Item 5', '40721.78', 'TAXES DUE', 'Due', 'Multiply Item 6 by Your', 'DTC', 'Jc7o', '1 / ?', '94', 'Dd', 'aaaa']
# ...

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import warnings
warnings.filterwarnings("ignore")

reader = easyocr.Reader(['en'],gpu = False)
image = cv2.imread('/home/vimalkumar.s/Documents/100 files/Good Doc/0502883000.tif')
res = image.copy()
width = res.shape[1]
height = res.shape[0]
wi = width * 0.95
he = height * 0.3
w = int(wi)
h = int(he)
y = 0
x1 = w * 0.45
x = int(x1)
crop = image[y:y+h, x:x+w]
im = crop.copy()
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
r_easy_ocr=reader.readtext(thresh,detail=0)
r_easy_ocr.append('aaaa')
#print(r_easy_ocr)
sym = [',','.']
final = []
for i in r_easy_ocr:
    for j in sym:
        if j in i:
            #print(i)
            index_1 = r_easy_ocr.index(i)
            index_2 = r_easy_ocr.index(i)+1
            #print(r_easy_ocr.index(i))
            check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
            if check_num.isdigit():
                r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
            final.append(r_easy_ocr)
print(final[0])

special_chars = [',','.',' ','  ',';', ':', '!', "*"]
z = []
for a in final[0]:
    for b in special_chars:
        if b in a:
            z.append(a)
print(z)

out_list = [''.join(filter(str.isalnum, string)) for string in z]
print(out_list)

y=[]
for i in out_list:
    if (i.isdigit()):
        y.append(int(i))
print(y)
print('TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-b910136aad30> in <module>
#       9 image = cv2.imread('/home/vimalkumar.s/Documents/100 files/Good Doc/0502883000.tif')
#      10 #res = image.copy()
# ---> 11 width = image.shape[1]
#      12 height = image.shape[0]
#      13 wi = width * 0.95
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import os
import warnings
warnings.filterwarnings("ignore")


reader = easyocr.Reader(['en'],gpu = False)
path = '/home/vimalkumar.s/Documents/Good Files/cells'
for img in os.listdir(path):
    image = cv2.imread(os.path.join(path,img))
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
    r_easy_ocr.append('aaaa')

    #print(r_easy_ocr)

    sym = [',','.']
    final = []
    for i in r_easy_ocr:
        for j in sym:
            if j in i:
                #print(i)
                index_1 = r_easy_ocr.index(i)
                index_2 = r_easy_ocr.index(i)+1
                #print(r_easy_ocr.index(i))
                check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
                if check_num.isdigit():
                    r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
                final.append(r_easy_ocr)
    #print(final[0])

    special_chars = [',','.',' ','  ',';', ':', '!', "*"]
    z = []
    for a in final[0]:
        for b in special_chars:
            if b in a:
                z.append(a)
    #print(z)

    out_list = [''.join(filter(str.isalnum, string)) for string in z]
    #print(out_list)

    y=[]
    for i in out_list:
        if (i.isdigit()):
            y.append(int(i))
    #print(y)
    print(img,'TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# 0945102000.tif TOTAL WAGES PAID 113874
# 0944689000.tif TOTAL WAGES PAID 600000
# 0944634000.tif TOTAL WAGES PAID 2603750
# 0944625000.tif TOTAL WAGES PAID 37743
# 0944614000.tif TOTAL WAGES PAID 2467
# 0944612000.tif TOTAL WAGES PAID 86118
# 0944627000.tif TOTAL WAGES PAID 1050000
# 0944657000.tif TOTAL WAGES PAID 811500
# 0954992000.tif TOTAL WAGES PAID 369050
# 0944626000.tif TOTAL WAGES PAID 15390
# 0945101000.tif TOTAL WAGES PAID 865017
# 0950125000.tif TOTAL WAGES PAID 345000
# 0944850000.tif TOTAL WAGES PAID 406500
# 0954965000.tif TOTAL WAGES PAID 895496000
# 0954969000.tif TOTAL WAGES PAID 954969000
# 0944655000.tif TOTAL WAGES PAID 811500
# 0950916000.tif TOTAL WAGES PAID 429775
# 0945110000.tif TOTAL WAGES PAID 185064
# 0944636000.tif TOTAL WAGES PAID 41650
# 0954958000.tif TOTAL WAGES PAID 6954988000
# 0944683000.tif TOTAL WAGES PAID 765000
# 0944633000.tif TOTAL WAGES PAID 438200
# ...

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import os
import warnings
warnings.filterwarnings("ignore")


reader = easyocr.Reader(['en'],gpu = False)
path = '/home/vimalkumar.s/Documents/100 files/Bad doc/test'
for img in os.listdir(path):
    image = cv2.imread(os.path.join(path,img))
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
    r_easy_ocr.append('aaaa')

    #print(r_easy_ocr)

    sym = [',','.']
    final = []
    for i in r_easy_ocr:
        for j in sym:
            if j in i:
                print(i)
                if i not in r_easy_ocr:
                    break
                else:
                    index_1 = r_easy_ocr.index(i)
                    index_2 = r_easy_ocr.index(i)+1
                    #print(r_easy_ocr.index(i))
                    check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
                    if check_num.isdigit():
                        r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
                    final.append(r_easy_ocr)
    print(final[0])
    special_chars = [',','.',' ','  ',';', ':', '!', "*"]
    z = []
    for a in final[0]:
        for b in special_chars:
            if b in a:
                z.append(a)
    #print(z)

    out_list = [''.join(filter(str.isalnum, string)) for string in z]
    #print(out_list)

    y=[]
    for i in out_list:
        if (i.isdigit()):
            y.append(int(i))
    #print(y)
    print('TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# 0109749000.tif TOTAL WAGES PAID 4316357
# 0103841000.tif TOTAL WAGES PAID 15054298
# 0110331000.tif TOTAL WAGES PAID 5770577
# 0104921000.tif TOTAL WAGES PAID 25642596
# 0101231000.tif TOTAL WAGES PAID 99454487
# 0105311000.tif TOTAL WAGES PAID 44405899
# 0100617000.tif TOTAL WAGES PAID 14220
# 0110432000.tif TOTAL WAGES PAID 1150000
# 0110276000.tif TOTAL WAGES PAID 27526110
# 0109374000.tif TOTAL WAGES PAID 0
# 0100477000.tif TOTAL WAGES PAID 33935047
# 0102108000.tif TOTAL WAGES PAID 0
# 0102281000.tif TOTAL WAGES PAID 7786950
# 0110228000.tif TOTAL WAGES PAID 8298131
# 0103998000.tif TOTAL WAGES PAID 12332296
# 0106842000.tif TOTAL WAGES PAID 25599630
# 0101426000.tif TOTAL WAGES PAID 12453094
# 0110040000.tif TOTAL WAGES PAID 747145143
# 0105901000.tif TOTAL WAGES PAID 2644981
# 0110309000.tif TOTAL WAGES PAID 1794075
# 0102866000.tif TOTAL WAGES PAID 37123809
# 0111158000.tif TOTAL WAGES PAID 4013896
# ...

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import warnings
warnings.filterwarnings("ignore")

reader = easyocr.Reader(['en'],gpu = False)
image = cv2.imread('/home/vimalkumar.s/Documents/100 files/Good Doc/0495868000.tif')
res = image.copy()
width = res.shape[1]
height = res.shape[0]
wi = width * 0.95
he = height * 0.3
w = int(wi)
h = int(he)
y = 0
x1 = w * 0.45
x = int(x1)
crop = res[y:y+h, x:x+w]
im = crop.copy()
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
r_easy_ocr=reader.readtext(thresh,detail=0)
r_easy_ocr.append('aaaa')
print(r_easy_ocr)
sym = [',','.']
final = []
for i in r_easy_ocr:
    for j in sym:
        if j in i:
            #print(i)
            index_1 = r_easy_ocr.index(i)
            index_2 = r_easy_ocr.index(i)+1
            #print(r_easy_ocr.index(i))
            check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
            if check_num.isdigit():
                r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
            final.append(r_easy_ocr)
print(final[0])

special_chars = [',','.',' ','  ',';', ':', '!', "*"]
z = []
for a in final[0]:
    for b in special_chars:
        if b in a:
            z.append(a)
#print(z)

out_list = [''.join(filter(str.isalnum, string)) for string in z]
#print(out_list)

y=[]
for i in out_list:
    if (i.isdigit()):
        y.append(int(i))
#print(y)
print('TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ['TY', '2 MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', '(DO NOT', '4-95868-0-00', '2020', 'USE)', '3 CALENDAR QUARTER', 'Date Paid', 'Ist', '2nd', '3rd', '4th', 'MUST HAVE AMOUNTS IN 4, 5, & 6,EVEN IF ZERO', 'TOTAL WAGES PAID', '1,800 . 00', '28', '5 WAGES PAID NN EXCESS OF', '11,500.00 PER WORKER', 'PER YEAR (Scc Instruction Shcct)', '0', '00', 'TAXABLE WAGES', '(Item 4 Minus Item 5)', '1800.00', 'aaaa']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-213-b8a3cba1f444> in <module>
#      33         if j in i:
#      34             #print(i)
# ---> 35             index_1 = r_easy_ocr.index(i)
#      36             index_2 = r_easy_ocr.index(i)+1
#      37             #print(r_easy_ocr.index(i))
#
# ValueError: '1,800 . 00' is not in list

# %%
sym = [',','.']
final = []
for i in r_easy_ocr:
    for j in sym:
        if j in i:
            #print(i)
            index_1 = r_easy_ocr.index(i)
            index_2 = r_easy_ocr.index(i)+1
            #print(r_easy_ocr.index(i))
            check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
            if check_num.isdigit():
                r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
            final.append(r_easy_ocr)
print(final[0])
# Out:
# ['TY', '2 MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', '(DO NOT', '4-95868-0-00', '2020', 'USE)', '3 CALENDAR QUARTER', 'Date Paid', 'Ist', '2nd', '3rd', '4th', 'MUST HAVE AMOUNTS IN 4, 5, & 6,EVEN IF ZERO', 'TOTAL WAGES PAID', '1,800 . 0028', '5 WAGES PAID NN EXCESS OF', '11,500.00 PER WORKER', 'PER YEAR (Scc Instruction Shcct)', '0', '00', 'TAXABLE WAGES', '(Item 4 Minus Item 5)', '1800.00', 'aaaa']

# %%
special_chars = [',','.',' ','  ',';', ':', '!', "*"]
z = []
for a in final[0]:
    for b in special_chars:
        if b in a:
            z.append(a)
#print(z)

out_list = [''.join(filter(str.isalnum, string)) for string in z]
#print(out_list)

y=[]
for i in out_list:
    if (i.isdigit()):
        y.append(int(i))
#print(y)
print('TOTAL WAGES PAID',max(y))
# Out:
# TOTAL WAGES PAID 18000028

# %%
    image = cv2.imread('/home/vimalkumar.s/Documents/100 files/Good Doc/0495868000.tif')
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
    r_easy_ocr.append('aaaa')

    print(r_easy_ocr)

    sym = [',','.']
    final = []
    for i in r_easy_ocr:
        for j in sym:
            if j in i:
                #print(i)
                index_1 = r_easy_ocr.index(i)
                index_2 = r_easy_ocr.index(i)+1
                #print(r_easy_ocr.index(i))
                check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
                if check_num.isdigit():
                    r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
                final.append(r_easy_ocr)
    #print(final[0])

    special_chars = [',','.',' ','  ',';', ':', '!', "*"]
    z = []
    for a in final[0]:
        for b in special_chars:
            if b in a:
                z.append(a)
    #print(z)

    out_list = [''.join(filter(str.isalnum, string)) for string in z]
    #print(out_list)

    y=[]
    for i in out_list:
        if (i.isdigit()):
            y.append(int(i))
    #print(y)
    print(img,'TOTAL WAGES PAID',max(y))
# Out:
# ['TY', '2 MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', '(DO NOT', '4-95868-0-00', '2020', 'USE)', '3 CALENDAR QUARTER', 'Date Paid', 'Ist', '2nd', '3rd', '4th', 'MUST HAVE AMOUNTS IN 4, 5, & 6,EVEN IF ZERO', 'TOTAL WAGES PAID', '1,800 . 00', '28', '5 WAGES PAID NN EXCESS OF', '11,500.00 PER WORKER', 'PER YEAR (Scc Instruction Shcct)', '0', '00', 'TAXABLE WAGES', '(Item 4 Minus Item 5)', '1800.00', 'aaaa']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-217-063e272adbce> in <module>
#      27         if j in i:
#      28             #print(i)
# ---> 29             index_1 = r_easy_ocr.index(i)
#      30             index_2 = r_easy_ocr.index(i)+1
#      31             #print(r_easy_ocr.index(i))
#
# ValueError: '1,800 . 00' is not in list

# %%
    import cv2
    import numpy as np
    import easyocr
    from PIL import Image
    import warnings
    warnings.filterwarnings("ignore")
    reader = easyocr.Reader(['en'],gpu = False)
    image = cv2.imread('/home/vimalkumar.s/Documents/100 files/Good Doc/0495868000.tif')
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
    r_easy_ocr.append('aaaa')
    r_easy_ocr.append('bbbb')
    print(r_easy_ocr)
    sym = [',','.']
    final = []
    for i in r_easy_ocr:
        for j in sym:
            if j in i:
                print(i)
                if i not in r_easy_ocr:
                    break
                else:
                    index_1 = r_easy_ocr.index(i)
                    index_2 = r_easy_ocr.index(i)+1
                    #print(r_easy_ocr.index(i))
                    check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
                    if check_num.isdigit():
                        r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
                    final.append(r_easy_ocr)
    print(final[0])
    special_chars = [',','.',' ','  ',';', ':', '!', "*"]
    z = []
    for a in final[0]:
        for b in special_chars:
            if b in a:
                z.append(a)
    #print(z)

    out_list = [''.join(filter(str.isalnum, string)) for string in z]
    #print(out_list)

    y=[]
    for i in out_list:
        if (i.isdigit()):
            y.append(int(i))
    #print(y)
    print('TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ['TY', '2 MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', '(DO NOT', '4-95868-0-00', '2020', 'USE)', '3 CALENDAR QUARTER', 'Date Paid', 'Ist', '2nd', '3rd', '4th', 'MUST HAVE AMOUNTS IN 4, 5, & 6,EVEN IF ZERO', 'TOTAL WAGES PAID', '1,800 . 00', '28', '5 WAGES PAID NN EXCESS OF', '11,500.00 PER WORKER', 'PER YEAR (Scc Instruction Shcct)', '0', '00', 'TAXABLE WAGES', '(Item 4 Minus Item 5)', '1800.00', 'aaaa', 'bbbb']
# MUST HAVE AMOUNTS IN 4, 5, & 6,EVEN IF ZERO
# 1,800 . 00
# 1,800 . 00
# 11,500.00 PER WORKER
# 11,500.00 PER WORKER
# 1800.00
# ...

# %%
r_easy_ocr
# Out:
# ['TY',
#  'OFoSsl-0-C',
#  '2 MO EMPLOYER ACCOUNT NO',
#  'YEAR',
#  'AUDIT',
#  '(DO NOT',
#  '12900284',
#  '2020',
#  'USE)',
#  'CALENDAR QUARTER',
#  'Date Pald',
#  'Ist',
#  '2nd',
#  '3rd',
#  'Ath',
#  'MUST HAVE AMOUNTS IN 4,5, & 6,EVEN IF ZERO',
#  '4 TOTAL WAGES PAID',
#  '72,375.70',
#  '27',
#  'WAGES PAID IN EXCESS OF',
#  '11,500',
#  '0 PER WORKER',
#  'PER YEAR (See Instruction Sheet)',
#  '52 , 575',
#  '70',
#  '6 TAXABLE WAGES',
#  '(Item 4 Minus Ilem 5)',
#  '19,800.00',
#  'aaaa',
#  'bbbb']

# %%
    sym = [',','.']
    final = []
    for i in r_easy_ocr:
        for j in sym:
            if j in i:
                print(i)
                if i not in r_easy_ocr:
                    break
                else:
                    index_1 = r_easy_ocr.index(i)
                    index_2 = r_easy_ocr.index(i)+1
                    #print(r_easy_ocr.index(i))
                    check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
                    if check_num.isdigit():
                        r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
                    final.append(r_easy_ocr)
    print(final[0])
    special_chars = [',','.',' ','  ',';', ':', '!', "*"]
    z = []
    for a in final[0]:
        for b in special_chars:
            if b in a:
                z.append(a)
    #print(z)

    out_list = [''.join(filter(str.isalnum, string)) for string in z]
    #print(out_list)

    y=[]
    for i in out_list:
        if (i.isdigit()):
            y.append(int(i))
    #print(y)
    print('TOTAL WAGES PAID',max(y))
# Out:
# MUST HAVE AMOUNTS IN 4,5, & 6,EVEN IF ZERO
# 72,375.7027
# 72,375.7027
# 11,500
# 52 , 575
# 19,800.00
# 19,800.00
# ['TY', 'OFoSsl-0-C', '2 MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', '(DO NOT', '12900284', '2020', 'USE)', 'CALENDAR QUARTER', 'Date Pald', 'Ist', '2nd', '3rd', 'Ath', 'MUST HAVE AMOUNTS IN 4,5, & 6,EVEN IF ZERO', '4 TOTAL WAGES PAID', '72,375.7027', 'WAGES PAID IN EXCESS OF', '11,500', '0 PER WORKER', 'PER YEAR (See Instruction Sheet)', '52 , 57570', '6 TAXABLE WAGES', '(Item 4 Minus Ilem 5)', '19,800.00', 'aaaa', 'bbbb']
# TOTAL WAGES PAID 723757027

# %%
    sym = [',','.']
    final = []
    for i in r_easy_ocr:
        for j in sym:
            if j in i:
                #print(i)
                index_1 = r_easy_ocr.index(i)
                index_2 = r_easy_ocr.index(i)+1
                #print(r_easy_ocr.index(i))
                check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
                if check_num.isdigit():
                    r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
                final.append(r_easy_ocr)
    print(final[0])
    
    special_chars = [',','.',' ','  ',';', ':', '!', "*"]
    z = []
    for a in final[0]:
        for b in special_chars:
            if b in a:
                z.append(a)
    #print(z)

    out_list = [''.join(filter(str.isalnum, string)) for string in z]
    #print(out_list)

    y=[]
    for i in out_list:
        if (i.isdigit()):
            y.append(int(i))
    #print(y)
    print(img,'TOTAL WAGES PAID',max(y))
# Out:
# ['TY', '2 MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', '(DO NOT', '4-95868-0-00', '2020', 'USE)', '3 CALENDAR QUARTER', 'Date Paid', 'Ist', '2nd', '3rd', '4th', 'MUST HAVE AMOUNTS IN 4, 5, & 6,EVEN IF ZERO', 'TOTAL WAGES PAID', '1,800 . 0028', '5 WAGES PAID NN EXCESS OF', '11,500.00 PER WORKER', 'PER YEAR (Scc Instruction Shcct)', '0', '00', 'TAXABLE WAGES', '(Item 4 Minus Item 5)', '1800.00', 'aaaa']
# 0497319000.tif TOTAL WAGES PAID 18000028

# %%
y=[]
if len(y) == 0:
    print(img,'TOTAL WAGES PAID',0)
else:
    print(img,'TOTAL WAGES PAID',max(y))
# Out:
# 0109374000.tif TOTAL WAGES PAID 0

# %%
    image = cv2.imread('/home/vimalkumar.s/Documents/100 files/test/0497041000.tif')
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
    r_easy_ocr.append('aaaa')

    print(r_easy_ocr)

    sym = [',','.']
    final = []
    for i in r_easy_ocr:
        for j in sym:
            if j in i:
                #print(i)
                if i not in r_easy_ocr:
                    break
                else:
                    index_1 = r_easy_ocr.index(i)
                    index_2 = r_easy_ocr.index(i)+1
                    #print(r_easy_ocr.index(i))
                    check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
                    if check_num.isdigit():
                        r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
                    final.append(r_easy_ocr)
    #print(final[0])
    special_chars = [',','.',' ','  ',';', ':', '!', "*"]
    z = []
    for a in final[0]:
        for b in special_chars:
            if b in a:
                z.append(a)
    #print(z)

    out_list = [''.join(filter(str.isalnum, string)) for string in z]
    #print(out_list)

    y=[]
    for i in out_list:
        if (i.isdigit()):
            y.append(int(i))
    #print(y)
    y_set = set(y)
    y = list(y_set)
    num = [11500,115000,1150000,]
    for k in y:
        if k in num:
            y.remove(k)
        print(y)
    #print(img,'TOTAL WAGES PAID',max(y))
    if len(y) == 0:
        print(img,'TOTAL WAGES PAID',0)
    else:
        print(img,'TOTAL WAGES PAID',max(y))
# Out:
# ['2', 'MISSOURI EMPLOYER ACCOUNT NO', 'AuDit BLOCK', '04-97041-0-00', '(DO NOT USE)', 'CALENDAR QUARTER', 'Date', '1/20', 'Paid', 'MUST HAVE AMOUNT IN 4, 5, & 6 EVEN IF "ZERO"', "'4", 'TOTAL WAGES PAID', '11500', '00', '"5', 'WAGES PAIDAIN-EXCESS', 'OF', '1i500 , 00', 'PER WORKER PER YEAR', '(See instructions)', '0', '001', '6', 'TAXABLE WAGES', 'Item 4 Minus Iter', '11500', '00', 'TAXES DUE', 'Dua', 'Multiply Item 6 by Your', 'aaaa']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-4fde4cac9e24> in <module>
#      61         y.remove(k)
#      62     print(y)
# ---> 63 print(img,'TOTAL WAGES PAID',max(y))
#      64 #if len(y) == 0:
#      65     #print(img,'TOTAL WAGES PAID',0)
#
# ValueError: max() arg is an empty sequence

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import os
import warnings
warnings.filterwarnings("ignore")


reader = easyocr.Reader(['en'],gpu = False)
path = '/home/vimalkumar.s/Documents/100 files/test'
for img in os.listdir(path):
    image = cv2.imread(os.path.join(path,img))
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
    r_easy_ocr.append('aaaa')

    #print(r_easy_ocr)

    sym = [',','.']
    final = []
    for i in r_easy_ocr:
        for j in sym:
            if j in i:
                #print(i)
                if i not in r_easy_ocr:
                    break
                else:
                    index_1 = r_easy_ocr.index(i)
                    index_2 = r_easy_ocr.index(i)+1
                    #print(r_easy_ocr.index(i))
                    check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
                    if check_num.isdigit():
                        r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
                    final.append(r_easy_ocr)
    #print(final[0])
    special_chars = [',','.',' ','  ',';', ':', '!', "*"]
    z = []
    for a in final[0]:
        for b in special_chars:
            if b in a:
                z.append(a)
    #print(z)

    out_list = [''.join(filter(str.isalnum, string)) for string in z]
    #print(out_list)

    y=[]
    for i in out_list:
        if (i.isdigit()):
            y.append(int(i))
    y_set = set(y)
    y = list(y_set)
    num = [11500,115000,1150000,]
    for k in y:
        if k in num:
            y.remove(k)
    #print(y)
    
    if len(y) == 0:
        print(img,'TOTAL WAGES PAID',0)
    else:
        print(img,'TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# 0500847001.tif TOTAL WAGES PAID 90754
# 0109749000.tif TOTAL WAGES PAID 4316357
# 0103841000.tif TOTAL WAGES PAID 15054298
# 0110331000.tif TOTAL WAGES PAID 5770577
# 0503866000.tif TOTAL WAGES PAID 11421015
# 0501500000.tif TOTAL WAGES PAID 1056000
# 0501239000.tif TOTAL WAGES PAID 42034488
# 0104921000.tif TOTAL WAGES PAID 25642596
# 0502465000.tif TOTAL WAGES PAID 1332100
# 0497812000.tif TOTAL WAGES PAID 3000000
# 0101231000.tif TOTAL WAGES PAID 99454487
# 0495949000.tif TOTAL WAGES PAID 891000
# 0105311000.tif TOTAL WAGES PAID 44405899
# 0498650000.tif TOTAL WAGES PAID 6019256
# 0502883000.tif TOTAL WAGES PAID 3239901
# 0100617000.tif TOTAL WAGES PAID 14220
# 0496106000.tif TOTAL WAGES PAID 19035118
# 0499741000.tif TOTAL WAGES PAID 450000
# 0110432000.tif TOTAL WAGES PAID 778800
# 0110276000.tif TOTAL WAGES PAID 27526110
# 0499439000.tif TOTAL WAGES PAID 16608439
# 0499639000.tif TOTAL WAGES PAID 12854493
# ...

# %%
import copy
import os

# %%
path = '/home/vimalkumar.s/Documents/file samples/500 Samples/500'
for img in os.listdir(path):
    #image = cv2.imread('/home/vimalkumar.s/Documents/file samples/100 files/Good Doc/0494564000.tif')
    image = cv2.imread(os.path.join(path,img))
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
    r_easy_ocr.append('aaaa')

    #print(r_easy_ocr)

    sym = [',','.']
    final = []
    for i in r_easy_ocr:
        for j in sym:
            if j in i:
                #print(i)
                if i not in r_easy_ocr:
                    break
                else:
                    index_1 = r_easy_ocr.index(i)
                    index_2 = r_easy_ocr.index(i)+1
                    #print(r_easy_ocr.index(i))
                    check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
                    if check_num.isdigit():
                        r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
                    final.append(r_easy_ocr)
    #print(final[0])
    if len(final) == 0:
        print(img,'TOTAL WAGES PAID',0)
    else:
        special_chars = [',','.',' ','  ',';', ':', '!', "*"]
        z = []
        for a in final[0]:
            for b in special_chars:
                if b in a:
                    z.append(a)
        #print(z)

        out_list = [''.join(filter(str.isalnum, string)) for string in z]
        #print(out_list)

        y=[]
        for i in out_list:
            if (i.isdigit()):
                y.append(int(i))
        #print(y)
        y_set = set(y)
        y = list(y_set)
        num = [11500,115000,1150000,]
        for k in y:
            if k in num:
                y.remove(k)
            #print(y)
        #print('TOTAL WAGES PAID',max(y))
        if len(y) == 0:
            print(img,'TOTAL WAGES PAID',0)
        else:
            print(img,'TOTAL WAGES PAID',max(y))
# Out:
# 0500847001.tif TOTAL WAGES PAID 90754
# 0285768000.tif TOTAL WAGES PAID 8000001
# 0109749000.tif TOTAL WAGES PAID 4316357
# 0913547000.tif TOTAL WAGES PAID 1200000
# 0942287000.tif TOTAL WAGES PAID 402875
# 0566623000.tif TOTAL WAGES PAID 0
# 0150519000.tif TOTAL WAGES PAID 6021677
# 0308918000.tif TOTAL WAGES PAID 1500000
# 0103841000.tif TOTAL WAGES PAID 15054298
# 0295204000.tif TOTAL WAGES PAID 7461214
# 0110331000.tif TOTAL WAGES PAID 5770577
# 0503866000.tif TOTAL WAGES PAID 11421015
# 0926344000.tif TOTAL WAGES PAID 2706942
# 0501500000.tif TOTAL WAGES PAID 1056000
# 0700642000.tif TOTAL WAGES PAID 1609829
# 0275157000.tif TOTAL WAGES PAID 2021800
# 0902276000.tif TOTAL WAGES PAID 0
# 0313322000.tif TOTAL WAGES PAID 11447387
# 0402387000.tif TOTAL WAGES PAID 16
# 0115514000.tif TOTAL WAGES PAID 3115000
# 0332179000.tif TOTAL WAGES PAID 5337293
# 0492651000.tif TOTAL WAGES PAID 756532951
# 0501239000.tif TOTAL WAGES PAID 42034488
# 0701790000.tif TOTAL WAGES PAID 83658
# ...

# %%
final
# Out:
# []

# %%
    image = cv2.imread('/home/vimalkumar.s/Documents/file samples/100 files/Good Doc/0494564000.tif')
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
    r_easy_ocr.append('aaaa')

    print(r_easy_ocr)

    sym = [',','.']
    final = []
    for i in r_easy_ocr:
        for j in sym:
            if j in i:
                print(i)
                if i not in r_easy_ocr:
                    break
                else:
                    index_1 = r_easy_ocr.index(i)
                    index_2 = r_easy_ocr.index(i)+1
                    #print(r_easy_ocr.index(i))
                    check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
                    if check_num.isdigit():
                        r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
                    final.append(r_easy_ocr)
    print(final[0])
    special_chars = [',','.',' ','  ',';', ':', '!', "*"]
    z = []
    for a in final[0]:
        for b in special_chars:
            if b in a:
                z.append(a)
    print(z)

    out_list = [''.join(filter(str.isalnum, string)) for string in z]
    print(out_list)

    y=[]
    for i in out_list:
        if (i.isdigit()):
            y.append(int(i))
    print(y)
    y_set = set(y)
    y = list(y_set)
    num = [11500,115000,1150000,]
    for k in y:
        if k in num:
            y.remove(k)
        print(y)
    print('TOTAL WAGES PAID',max(y))
    if len(y) == 0:
        print('TOTAL WAGES PAID',0)
    else:
        print('TOTAL WAGES PAID',max(y))
# Out:
# ['Y', 'MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', '(DO NOT', '04-94564-0-00', '2020', 'USE)', '3 CALENDAR QUARTER', 'Date Paid', 'Ist', '2nd', '3rd', 'X', '4th', 'MUST HAVE AMOUNTS IN 4,5, & 6 EVEN IF ZERO', 'TOTAL WAGES PAID', '93, 653.12', 'WAGES PAID IN EXCESS OF', '11,500', '00', 'PER WORKER', 'PER YEAR', ' See Instruction Sheet)', '87,711.12', '6 TAXABLE WAGES', '(Item 4 Minus Item 5)', '5, 942.00', 'aaaa']
# MUST HAVE AMOUNTS IN 4,5, & 6 EVEN IF ZERO
# 93, 653.12
# 93, 653.12
# 11,500
# 87,711.12
# 87,711.12
# 5, 942.00
# 5, 942.00
# ['Y', 'MO EMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', '(DO NOT', '04-94564-0-00', '2020', 'USE)', '3 CALENDAR QUARTER', 'Date Paid', 'Ist', '2nd', '3rd', 'X', '4th', 'MUST HAVE AMOUNTS IN 4,5, & 6 EVEN IF ZERO', 'TOTAL WAGES PAID', '93, 653.12', 'WAGES PAID IN EXCESS OF', '11,50000', 'PER WORKER', 'PER YEAR', ' See Instruction Sheet)', '87,711.12', '6 TAXABLE WAGES', '(Item 4 Minus Item 5)', '5, 942.00', 'aaaa']
# ...

# %%
    image = cv2.imread('/home/vimalkumar.s/Documents/file samples/100 files/Good Doc/0503866000.tif')
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
    r_easy_ocr.append('aaaa')

    print(r_easy_ocr)

    sym = [',','.']
    final = []
    for i in r_easy_ocr:
        for j in sym:
            if j in i:
                print(i)
                if i not in r_easy_ocr:
                    break
                else:
                    index_1 = r_easy_ocr.index(i)
                    index_2 = r_easy_ocr.index(i)+1
                    #print(r_easy_ocr.index(i))
                    check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
                    if check_num.isdigit():
                        r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
                    final.append(r_easy_ocr)
    print(final[0])
    special_chars = [',','.',' ']
    z = []
    for a in final[0]:
        for b in special_chars:
            if b in a:
                z.append(a)
    print(z)

    out_list = [''.join(filter(str.isalnum, string)) for string in z]
    print(out_list)

    y=[]
    for i in out_list:
        if (i.isdigit()):
            y.append(int(i))
    print(y)
    y_set = set(y)
    y = list(y_set)
    num = [11500,115000,1150000,]
    for k in y:
        if k in num:
            y.remove(k)
        print(y)
    print('TOTAL WAGES PAID',max(y))
    if len(y) == 0:
        print('TOTAL WAGES PAID',0)
    else:
        print('TOTAL WAGES PAID',max(y))
# Out:
# ['TY', '2 MOEMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', '(DO NOT', '05-03866-0-00', '2020', 'USE)', 'CALENDAR QUARTER', 'Datc Paid', 'Ist', '2nd', '3rd', 'Ath', 'MUST HAVE AMOUNTS IN 4,5, & 6, EVEN IF ZERO', 'TOTAL WAGES PAJD', '114,210', '15', '5 WAGES PAID IN EXCESS OF', '11,500', '0 PER WORKER', 'PER YEAR (Sce Instruction Shcet)', '82 , 602 . 56', '6 TAXABLE WAGES', '(Item 4 Minus Item 5)', '31, 607.59', 'aaaa']
# MUST HAVE AMOUNTS IN 4,5, & 6, EVEN IF ZERO
# 114,210
# 11,500
# 82 , 602 . 56
# 82 , 602 . 56
# 31, 607.59
# 31, 607.59
# ['TY', '2 MOEMPLOYER ACCOUNT NO', 'YEAR', 'AUDIT', '(DO NOT', '05-03866-0-00', '2020', 'USE)', 'CALENDAR QUARTER', 'Datc Paid', 'Ist', '2nd', '3rd', 'Ath', 'MUST HAVE AMOUNTS IN 4,5, & 6, EVEN IF ZERO', 'TOTAL WAGES PAJD', '114,21015', '5 WAGES PAID IN EXCESS OF', '11,500', '0 PER WORKER', 'PER YEAR (Sce Instruction Shcet)', '82 , 602 . 56', '6 TAXABLE WAGES', '(Item 4 Minus Item 5)', '31, 607.59', 'aaaa']
# ...

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import os
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import re

reader = easyocr.Reader(['en'],gpu = False)
path = '/home/vimalkumar.s/Documents/file samples/500 Samples SET 2/500'
for img in os.listdir(path):
    image = cv2.imread(os.path.join(path,img))
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
    #print(r_easy_ocr)
    
    word = 'TOTAL WAGES PAID'
    for w in r_easy_ocr:
        if fuzz.ratio(word,w) > 85:
            #print(w)
            index_1 = r_easy_ocr.index(w) + 1
            #print(index_1)      
            text_1 = r_easy_ocr[index_1]
            #print(text_1)
            num_1 = re.sub("[ ,.#*!@$%^&()|\''"":;]", "", text_1)
            #print(num_1)
            index_2 = index_1 + 1
            #print(index_2)
            check_num = r_easy_ocr[index_2]
            #print(check_num)
            if check_num.isdigit():
                join = "".join([num_1, check_num])
                print(img, 'TOTAL WAGES PAID' , join)
            else:
                print(img, 'TOTAL WAGES PAID' , num_1)
# Out:
# /home/vimalkumar.s/Documents/python_new/cde_venv/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# Using CPU. Note: This module is much faster with a GPU.
# /home/vimalkumar.s/Documents/python_new/cde_venv/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 0378019000.tif TOTAL WAGES PAID 2101400
# 0390930000.tif TOTAL WAGES PAID 1182000
# 0481147000.tif TOTAL WAGES PAID 2652088
# 0393225000.tif TOTAL WAGES PAID 81213
# ...

# %%
import cv2
import numpy as np
import easyocr
from PIL import Image
import os
import warnings
warnings.filterwarnings("ignore")


reader = easyocr.Reader(['en'],gpu = False)
path = '/home/vimalkumar.s/Documents/file samples/500 Samples SET 2/500'
for img in os.listdir(path):
    image = cv2.imread(os.path.join(path,img))
    res = image.copy()
    width = res.shape[1]
    height = res.shape[0]
    wi = width * 0.95
    he = height * 0.3
    w = int(wi)
    h = int(he)
    y = 0
    x1 = w * 0.45
    x = int(x1)
    crop = res[y:y+h, x:x+w]
    im = crop.copy()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
    sharpen = cv2.filter2D(gray, -1, sharpen_kernel)
    thresh = cv2.threshold(sharpen, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
    r_easy_ocr=reader.readtext(thresh,detail=0)
    r_easy_ocr.append('aaaa')

    #print(r_easy_ocr)

    sym = [',','.']
    final = []
    for i in r_easy_ocr:
        for j in sym:
            if j in i:
                #print(i)
                if i not in r_easy_ocr:
                    break
                else:
                    index_1 = r_easy_ocr.index(i)
                    index_2 = r_easy_ocr.index(i)+1
                    #print(r_easy_ocr.index(i))
                    check_num = r_easy_ocr[r_easy_ocr.index(i)+1]
                    if check_num.isdigit():
                        r_easy_ocr[index_1 : index_2+1] = [''.join(r_easy_ocr[index_1 : index_2+1])]
                    final.append(r_easy_ocr)
    #print(final[0])
    if len(final) == 0:
        print(img,'TOTAL WAGES PAID',0)
    else:
        
        special_chars = [',','.',' ','  ',';', ':', '!', "*"]
        z = []
        for a in final[0]:
            for b in special_chars:
                if b in a:
                    z.append(a)
        #print(z)

        out_list = [''.join(filter(str.isalnum, string)) for string in z]
        #print(out_list)

        y=[]
        for i in out_list:
            if (i.isdigit()):
                y.append(int(i))
        y_set = set(y)
        y = list(y_set)
        num = [11500,115000,1150000,]
        for k in y:
            if k in num:
                y.remove(k)
        #print(y)

        if len(y) == 0:
            print(img,'TOTAL WAGES PAID',0)
        else:
            print(img,'TOTAL WAGES PAID',max(y))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# 0378019000.tif TOTAL WAGES PAID 2101400
# 0390930000.tif TOTAL WAGES PAID 1182000
# 0481147000.tif TOTAL WAGES PAID 2652088
# 0393225000.tif TOTAL WAGES PAID 979
# 0126895000.tif TOTAL WAGES PAID 29215355
# 0389561000.tif TOTAL WAGES PAID 6883047
# 0378945000.tif TOTAL WAGES PAID 13721613
# 0408602000.tif TOTAL WAGES PAID 79650
# 0505105000.tif TOTAL WAGES PAID 4960995
# 0414534000.tif TOTAL WAGES PAID 4519728
# 0529907000.tif TOTAL WAGES PAID 10000
# 0127376000.tif TOTAL WAGES PAID 8820204
# 0528701000.tif TOTAL WAGES PAID 1401399
# 0121790000.tif TOTAL WAGES PAID 1250000
# 0439580000.tif TOTAL WAGES PAID 118679
# 0121653000.tif TOTAL WAGES PAID 32300650
# 0164908000.tif TOTAL WAGES PAID 9834417
# 0529709000.tif TOTAL WAGES PAID 7550010
# 0489279000.tif TOTAL WAGES PAID 615913
# 0408608000.tif TOTAL WAGES PAID 1323560
# 0173473000.tif TOTAL WAGES PAID 1015650
# 0126103000.tif TOTAL WAGES PAID 1109436
# ...
